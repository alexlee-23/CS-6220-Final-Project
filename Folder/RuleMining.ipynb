# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\aidhe\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aidhe\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aidhe\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aidhe\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\aidhe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
pd.set_option('display.max_columns', None)

# %%
Csv = pd.read_csv('BatterInformation.csv')
filteredCSV = Csv[(Csv['year'] >= 2022) & (Csv['year'] < 2025)]

# %%
Pitchers = pd.read_csv('Pitchers_With_Clusters.csv')
filteredPitchers = Pitchers[(Pitchers['year'] >= 2022) & (Pitchers['year'] < 2025)]

# %%
display(filteredPitchers)
# Out:
#       player_id  year last_name, first_name  kmeans_quality_cluster  \
# 4        425794  2022      Wainwright, Adam                       1
# 5        425794  2023      Wainwright, Adam                       5
# 9        425844  2022         Greinke, Zack                       3
# 10       425844  2023         Greinke, Zack                       3
# 17       434378  2022     Verlander, Justin                       7
# ...         ...   ...                   ...                     ...
# 2208     695243  2024         Miller, Mason                       2
# 2212     700249  2024          Povich, Cade                       1
# 2215     701581  2024          Festa, David                       3
# 2220     806185  2024      Birdsong, Hayden                       3
# 2223     808967  2024   Yamamoto, Yoshinobu                       1
#
#                       quality_archetype  impact_cluster  \
# 4          League-Average Pitch Quality               2
# 5              Sinkers Get Hit (Bad SI)               1
# 9          Weak Fastball Group (Bad FF)               0
# 10         Weak Fastball Group (Bad FF)               0
# 17               Slider Aces (Elite SL)               5
# ...                                 ...             ...
# 2208  Four-Seam Aces (Elite FF Quality)               5
# 2212       League-Average Pitch Quality               2
# 2215       Weak Fastball Group (Bad FF)               0
# 2220       Weak Fastball Group (Bad FF)               0
# 2223       League-Average Pitch Quality               2
#
#                                      impact_archetype
# 4       Balanced Positive Arsenal (Mild Impact Gains)
# 5     Sinker Liability Pitchers (Sinker Gets Crushed)
# 9         FF Liability Pitchers (Bad Fastball Impact)
# 10        FF Liability Pitchers (Bad Fastball Impact)
# 17                   Four-Seam Aces (Elite FF Impact)
# ...                                               ...
# 2208                 Four-Seam Aces (Elite FF Impact)
# 2212    Balanced Positive Arsenal (Mild Impact Gains)
# 2215      FF Liability Pitchers (Bad Fastball Impact)
# 2220      FF Liability Pitchers (Bad Fastball Impact)
# 2223    Balanced Positive Arsenal (Mild Impact Gains)
#
# [923 rows x 7 columns]

# %%
display(filteredCSV)
# Out:
#      last_name, first_name  player_id  year  Cluster_Group  \
# 982           Cruz, Nelson     443558  2022              2
# 983      Blackmon, Charlie     453568  2022              0
# 984      McCutchen, Andrew     457705  2022              2
# 985         Turner, Justin     457759  2022              2
# 986          Andrus, Elvis     462101  2022              0
# ...                    ...        ...   ...            ...
# 1370      Chourio, Jackson     694192  2024              2
# 1371       Schanuel, Nolan     694384  2024              0
# 1372       Langford, Wyatt     694671  2024              2
# 1373          Young, Jacob     696285  2024              0
# 1374      Merrill, Jackson     701538  2024              2
#
#                    Hitter_Types  Cluster_Group.1       Ball Preference  \
# 982            Balanced Hitters                2   Aggressive Fastball
# 983   Hitters With Good Contact                2   Aggressive Fastball
# 984            Balanced Hitters                2   Aggressive Fastball
# 985            Balanced Hitters                2   Aggressive Fastball
# 986   Hitters With Good Contact                0  Selective / Moderate
# ...                         ...              ...                   ...
# 1370           Balanced Hitters                0  Selective / Moderate
# 1371  Hitters With Good Contact                0  Selective / Moderate
# 1372           Balanced Hitters                0  Selective / Moderate
# 1373  Hitters With Good Contact                0  Selective / Moderate
# 1374           Balanced Hitters                0  Selective / Moderate
#
#       Cluster_Group.2 Swinging Tendencies
# 982                 1            Balanced
# 983                 0          Aggressive
# 984                 1            Balanced
# 985                 2           Selective
# 986                 2           Selective
# ...               ...                 ...
# 1370                0          Aggressive
# 1371                2           Selective
# 1372                1            Balanced
# 1373                2           Selective
# 1374                0          Aggressive
#
# [393 rows x 9 columns]

# %%
#2022 Data
Events = pd.read_csv('statcast_pitch_by_pitch_2022.csv')
CondensedEvent = Events[['game_date','batter','pitcher','events','pitch_name','year']].copy()
CondensedEvent_no_out = CondensedEvent[~CondensedEvent['events'].str.contains('out|double_play|triple_play', case=False, na=False)]

# %%
merged = CondensedEvent_no_out.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean = merged.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete = df_clean.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete)
# Out:
#         game_date  batter  pitcher    events       pitch_name  year  \
# 0      2022-11-05  608324   502085    single    Knuckle Curve  2022
# 1      2022-11-05  514888   621107    single        Curveball  2022
# 2      2022-11-05  608324   621237      walk           Cutter  2022
# 3      2022-11-05  670541   621237  home_run           Sinker  2022
# 4      2022-11-05  665161   554430    single           Sinker  2022
# ...           ...     ...      ...       ...              ...   ...
# 20282  2022-03-19  665489   605400  home_run         Changeup  2022
# 20283  2022-03-19  668804   656638    single    Knuckle Curve  2022
# 20284  2022-03-18  650402   608717    single  4-Seam Fastball  2022
# 20285  2022-03-18  650402   640444      walk         Changeup  2022
# 20286  2022-03-18  643396   640444    double           Sinker  2022
#
#       last_name, first_name_x  player_id_x  Cluster_Group  \
# 0               Bregman, Alex     608324.0            2.0
# 1                Altuve, Jose     514888.0            0.0
# 2               Bregman, Alex     608324.0            2.0
# 3             Alvarez, Yordan     670541.0            1.0
# 4                Peña, Jeremy     665161.0            2.0
# ...                       ...          ...            ...
# 20282  Guerrero Jr., Vladimir     665489.0            1.0
# 20283         Reynolds, Bryan     668804.0            2.0
# 20284         Torres, Gleyber     650402.0            2.0
# 20285         Torres, Gleyber     650402.0            2.0
# 20286     Kiner-Falefa, Isiah     643396.0            0.0
#
#                     Hitter_Types  Cluster_Group.1       Ball Preference  \
# 0               Balanced Hitters              0.0  Selective / Moderate
# 1      Hitters With Good Contact              0.0  Selective / Moderate
# 2               Balanced Hitters              0.0  Selective / Moderate
# 3                  Power Hitters              0.0  Selective / Moderate
# 4               Balanced Hitters              0.0  Selective / Moderate
# ...                          ...              ...                   ...
# 20282              Power Hitters              0.0  Selective / Moderate
# 20283           Balanced Hitters              0.0  Selective / Moderate
# 20284           Balanced Hitters              0.0  Selective / Moderate
# 20285           Balanced Hitters              0.0  Selective / Moderate
# 20286  Hitters With Good Contact              2.0   Aggressive Fastball
#
#        Cluster_Group.2 Swinging Tendencies  player_id_y  \
# 0                  2.0           Selective       502085
# 1                  2.0           Selective       621107
# 2                  2.0           Selective       621237
# 3                  1.0            Balanced       621237
# 4                  0.0          Aggressive       554430
# ...                ...                 ...          ...
# 20282              0.0          Aggressive       605400
# 20283              0.0          Aggressive       656638
# 20284              1.0            Balanced       608717
# 20285              1.0            Balanced       640444
# 20286              2.0           Selective       640444
#
#       last_name, first_name_y  kmeans_quality_cluster  \
# 0            Robertson, David                       1
# 1                 Eflin, Zach                       0
# 2              Alvarado, José                       1
# 3              Alvarado, José                       1
# 4               Wheeler, Zack                       9
# ...                       ...                     ...
# 20282             Nola, Aaron                       0
# 20283             Lange, Alex                       1
# 20284         Stratton, Chris                       1
# 20285              Crowe, Wil                       6
# 20286              Crowe, Wil                       6
#
#                               quality_archetype  impact_cluster  \
# 0                  League-Average Pitch Quality               2
# 1      Fastball Generalists (Good FF + Good SI)               2
# 2                  League-Average Pitch Quality               2
# 3                  League-Average Pitch Quality               2
# 4                        Cutter Aces (Elite FC)               5
# ...                                         ...             ...
# 20282  Fastball Generalists (Good FF + Good SI)               5
# 20283              League-Average Pitch Quality               2
# 20284              League-Average Pitch Quality               2
# 20285         Weak Breaking Ball Group (Bad SL)               2
# 20286         Weak Breaking Ball Group (Bad SL)               2
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3      Balanced Positive Arsenal (Mild Impact Gains)
# 4                   Four-Seam Aces (Elite FF Impact)
# ...                                              ...
# 20282               Four-Seam Aces (Elite FF Impact)
# 20283  Balanced Positive Arsenal (Mild Impact Gains)
# 20284  Balanced Positive Arsenal (Mild Impact Gains)
# 20285  Balanced Positive Arsenal (Mild Impact Gains)
# 20286  Balanced Positive Arsenal (Mild Impact Gains)
#
# [20287 rows x 20 columns]

# %%
#2023
Events2023 = pd.read_csv('statcast_pitch_by_pitch_2023.csv')
CondensedEvent2023 = Events2023[['game_date','batter','pitcher','events','pitch_name','year']].copy()
CondensedEvent_no_out2023 = CondensedEvent2023[~CondensedEvent2023['events'].str.contains('out|double_play|triple_play', case=False, na=False)]

display(CondensedEvent_no_out2023)
# Out:
#          game_date  batter  pitcher  events       pitch_name  year
# 1       2023-11-01  606466   622250     NaN  4-Seam Fastball  2023
# 2       2023-11-01  606466   622250     NaN        Curveball  2023
# 3       2023-11-01  606466   622250     NaN  4-Seam Fastball  2023
# 4       2023-11-01  606466   622250     NaN  4-Seam Fastball  2023
# 6       2023-11-01  682998   622250     NaN        Curveball  2023
# ...            ...     ...      ...     ...              ...   ...
# 774031  2023-03-15  670231   641540     NaN              NaN  2023
# 774032  2023-03-15  670231   641540     NaN              NaN  2023
# 774035  2023-03-15  668472   641540     NaN              NaN  2023
# 774036  2023-03-15  668472   641540     NaN              NaN  2023
# 774037  2023-03-15  681987   641540  double              NaN  2023
#
# [640187 rows x 6 columns]

# %%
merged2 = CondensedEvent_no_out2023.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean2 = merged2.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete2 = df_clean2.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete2)
# Out:
#         game_date  batter  pitcher    events       pitch_name  year  \
# 0      2023-11-01  608369   623149    single          Sweeper  2023
# 1      2023-11-01  543760   623149  home_run  4-Seam Fastball  2023
# 2      2023-11-01  663993   623149    single  4-Seam Fastball  2023
# 3      2023-11-01  673962   623149    single  4-Seam Fastball  2023
# 4      2023-11-01  608369   656464      walk           Slider  2023
# ...           ...     ...      ...       ...              ...   ...
# 20737  2023-03-15  683011   605400      walk  4-Seam Fastball  2023
# 20738  2023-03-15  592206   622663      walk  4-Seam Fastball  2023
# 20739  2023-03-15  592206   622663    single         Changeup  2023
# 20740  2023-03-15  669261   592332      walk     Split-Finger  2023
# 20741  2023-03-15  669261   592332      walk     Split-Finger  2023
#
#       last_name, first_name_x  player_id_x  Cluster_Group      Hitter_Types  \
# 0               Seager, Corey     608369.0            1.0     Power Hitters
# 1              Semien, Marcus     543760.0            2.0  Balanced Hitters
# 2             Lowe, Nathaniel     663993.0            2.0  Balanced Hitters
# 3                  Jung, Josh     673962.0            1.0     Power Hitters
# 4               Seager, Corey     608369.0            1.0     Power Hitters
# ...                       ...          ...            ...               ...
# 20737          Volpe, Anthony     683011.0            2.0  Balanced Hitters
# 20738       Castellanos, Nick     592206.0            2.0  Balanced Hitters
# 20739       Castellanos, Nick     592206.0            2.0  Balanced Hitters
# 20740          Suwinski, Jack     669261.0            1.0     Power Hitters
# 20741          Suwinski, Jack     669261.0            1.0     Power Hitters
#
#        Cluster_Group.1       Ball Preference  Cluster_Group.2  \
# 0                  0.0  Selective / Moderate              0.0
# 1                  0.0  Selective / Moderate              2.0
# 2                  2.0   Aggressive Fastball              1.0
# 3                  0.0  Selective / Moderate              0.0
# 4                  0.0  Selective / Moderate              0.0
# ...                ...                   ...              ...
# 20737              0.0  Selective / Moderate              1.0
# 20738              0.0  Selective / Moderate              0.0
# 20739              0.0  Selective / Moderate              0.0
# 20740              0.0  Selective / Moderate              1.0
# 20741              0.0  Selective / Moderate              1.0
#
#       Swinging Tendencies  player_id_y last_name, first_name_y  \
# 0              Aggressive       623149            Sewald, Paul
# 1               Selective       623149            Sewald, Paul
# 2                Balanced       623149            Sewald, Paul
# 3              Aggressive       623149            Sewald, Paul
# 4              Aggressive       656464           Ginkel, Kevin
# ...                   ...          ...                     ...
# 20737            Balanced       605400             Nola, Aaron
# 20738          Aggressive       622663          Severino, Luis
# 20739          Aggressive       622663          Severino, Luis
# 20740            Balanced       592332          Gausman, Kevin
# 20741            Balanced       592332          Gausman, Kevin
#
#        kmeans_quality_cluster                  quality_archetype  \
# 0                           2  Four-Seam Aces (Elite FF Quality)
# 1                           2  Four-Seam Aces (Elite FF Quality)
# 2                           2  Four-Seam Aces (Elite FF Quality)
# 3                           2  Four-Seam Aces (Elite FF Quality)
# 4                           7             Slider Aces (Elite SL)
# ...                       ...                                ...
# 20737                       2  Four-Seam Aces (Elite FF Quality)
# 20738                       3       Weak Fastball Group (Bad FF)
# 20739                       3       Weak Fastball Group (Bad FF)
# 20740                       1       League-Average Pitch Quality
# 20741                       1       League-Average Pitch Quality
#
#        impact_cluster                               impact_archetype
# 0                   5               Four-Seam Aces (Elite FF Impact)
# 1                   5               Four-Seam Aces (Elite FF Impact)
# 2                   5               Four-Seam Aces (Elite FF Impact)
# 3                   5               Four-Seam Aces (Elite FF Impact)
# 4                   4              Slider Aces (Elite Slider Impact)
# ...               ...                                            ...
# 20737               2  Balanced Positive Arsenal (Mild Impact Gains)
# 20738               0    FF Liability Pitchers (Bad Fastball Impact)
# 20739               0    FF Liability Pitchers (Bad Fastball Impact)
# 20740               2  Balanced Positive Arsenal (Mild Impact Gains)
# 20741               2  Balanced Positive Arsenal (Mild Impact Gains)
#
# [20742 rows x 20 columns]

# %%
#2024
Events2024 = pd.read_csv('statcast_pitch_by_pitch_2024.csv')
CondensedEvent2024 = Events2024[['game_date','batter','pitcher','events','pitch_name','year']].copy()
CondensedEvent_no_out2024 = CondensedEvent2024[~CondensedEvent2024['events'].str.contains('out|double_play|triple_play', case=False, na=False)]
display(CondensedEvent_no_out2024)
# Out:
#          game_date  batter  pitcher  events       pitch_name  year
# 1       2024-10-30  657077   621111     NaN    Knuckle Curve  2024
# 2       2024-10-30  657077   621111     NaN           Cutter  2024
# 3       2024-10-30  657077   621111     NaN    Knuckle Curve  2024
# 5       2024-10-30  669224   621111     NaN  4-Seam Fastball  2024
# 6       2024-10-30  669224   621111     NaN    Knuckle Curve  2024
# ...            ...     ...      ...     ...              ...   ...
# 760238  2024-03-15  521692   595881     NaN              NaN  2024
# 760239  2024-03-15  521692   595881     NaN              NaN  2024
# 760243  2024-03-15  666310   663903     NaN              NaN  2024
# 760244  2024-03-15  666310   663903     NaN              NaN  2024
# 760245  2024-03-15  608070   663903  double              NaN  2024
#
# [627915 rows x 6 columns]

# %%
merged3 = CondensedEvent_no_out2024.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean3 = merged3.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete3 = df_clean3.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete3)
# Out:
#         game_date  batter  pitcher          events       pitch_name  year  \
# 0      2024-10-30  606192   596133          single  4-Seam Fastball  2024
# 1      2024-10-30  605141   596133         sac_fly  4-Seam Fastball  2024
# 2      2024-10-30  660271   596133  catcher_interf         Changeup  2024
# 3      2024-10-30  669257   592454            walk         Changeup  2024
# 4      2024-10-30  606192   605280            walk           Sinker  2024
# ...           ...     ...      ...             ...              ...   ...
# 19270  2024-03-15  605137   571927          single           Sinker  2024
# 19271  2024-03-15  650333   571927          double         Changeup  2024
# 19272  2024-03-15  650559   571927            walk           Slider  2024
# 19273  2024-03-15  665862   571927          single           Sinker  2024
# 19274  2024-03-15  605137   571927            walk           Sinker  2024
#
#       last_name, first_name_x  player_id_x  Cluster_Group  \
# 0          Hernández, Teoscar     606192.0            1.0
# 1               Betts, Mookie     605141.0            2.0
# 2              Ohtani, Shohei     660271.0            1.0
# 3                 Smith, Will     669257.0            2.0
# 4          Hernández, Teoscar     606192.0            1.0
# ...                       ...          ...            ...
# 19270              Bell, Josh     605137.0            2.0
# 19271            Arraez, Luis     650333.0            0.0
# 19272       De La Cruz, Bryan     650559.0            2.0
# 19273      Chisholm Jr., Jazz     665862.0            2.0
# 19274              Bell, Josh     605137.0            2.0
#
#                     Hitter_Types  Cluster_Group.1       Ball Preference  \
# 0                  Power Hitters              0.0  Selective / Moderate
# 1               Balanced Hitters              0.0  Selective / Moderate
# 2                  Power Hitters              0.0  Selective / Moderate
# 3               Balanced Hitters              2.0   Aggressive Fastball
# 4                  Power Hitters              0.0  Selective / Moderate
# ...                          ...              ...                   ...
# 19270           Balanced Hitters              0.0  Selective / Moderate
# 19271  Hitters With Good Contact              2.0   Aggressive Fastball
# 19272           Balanced Hitters              0.0  Selective / Moderate
# 19273           Balanced Hitters              0.0  Selective / Moderate
# 19274           Balanced Hitters              0.0  Selective / Moderate
#
#        Cluster_Group.2 Swinging Tendencies  player_id_y  \
# 0                  1.0            Balanced       596133
# 1                  2.0           Selective       596133
# 2                  1.0            Balanced       596133
# 3                  2.0           Selective       592454
# 4                  1.0            Balanced       605280
# ...                ...                 ...          ...
# 19270              0.0          Aggressive       571927
# 19271              2.0           Selective       571927
# 19272              0.0          Aggressive       571927
# 19273              1.0            Balanced       571927
# 19274              0.0          Aggressive       571927
#
#       last_name, first_name_y  kmeans_quality_cluster  \
# 0                Weaver, Luke                       1
# 1                Weaver, Luke                       1
# 2                Weaver, Luke                       1
# 3               Kahnle, Tommy                       8
# 4                Holmes, Clay                       1
# ...                       ...                     ...
# 19270            Matz, Steven                       0
# 19271            Matz, Steven                       0
# 19272            Matz, Steven                       0
# 19273            Matz, Steven                       0
# 19274            Matz, Steven                       0
#
#                               quality_archetype  impact_cluster  \
# 0                  League-Average Pitch Quality               2
# 1                  League-Average Pitch Quality               2
# 2                  League-Average Pitch Quality               2
# 3               Changeup Specialists (Elite CH)               2
# 4                  League-Average Pitch Quality               2
# ...                                         ...             ...
# 19270  Fastball Generalists (Good FF + Good SI)               3
# 19271  Fastball Generalists (Good FF + Good SI)               3
# 19272  Fastball Generalists (Good FF + Good SI)               3
# 19273  Fastball Generalists (Good FF + Good SI)               3
# 19274  Fastball Generalists (Good FF + Good SI)               3
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3      Balanced Positive Arsenal (Mild Impact Gains)
# 4      Balanced Positive Arsenal (Mild Impact Gains)
# ...                                              ...
# 19270              Sinker Aces (Elite Sinker Impact)
# 19271              Sinker Aces (Elite Sinker Impact)
# 19272              Sinker Aces (Elite Sinker Impact)
# 19273              Sinker Aces (Elite Sinker Impact)
# 19274              Sinker Aces (Elite Sinker Impact)
#
# [19275 rows x 20 columns]

# %%
#Finding the Rules
#Outcomes 2022
transactions22 = complete[['events','Swinging Tendencies','quality_archetype']].copy()

# %%
for col in transactions22.columns:
    transactions22[col] = transactions22[col].astype(str)
    transactions22[col] = col + "_" + transactions22[col]

# %%
transactionLists = transactions22.values.tolist()

# %%
#One Hot Encoding 
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)

# %%
#Apirori ItemSet
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)

# %%
#Rules (Swinging Techinque and quality_archetype)	
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
firstCleaned.sort_values(by='confidence', ascending=False, inplace=True)
firstCleanedHR = firstCleaned[firstCleaned['consequents'].apply(lambda x: any('home_run' in item for item in x))]
display(firstCleanedHR)
# Out:
#                                            antecedents        consequents  \
# 348  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 98                        (Hitter_Types_Power Hitters)  (events_home_run)
# 844  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 570  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 414  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 124  (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 408  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 34              (Ball Preference_Selective / Moderate)  (events_home_run)
# 122  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 676  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 492  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 246  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 60                     (Hitter_Types_Balanced Hitters)  (events_home_run)
# 8                (Ball Preference_Aggressive Fastball)  (events_home_run)
# 306  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 82            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 348            0.293593            0.103554  0.039896    0.135890  1.312262
# 98             0.342776            0.103554  0.045499    0.132738  1.281826
# 844            0.177951            0.103554  0.023087    0.129738  1.252852
# 570            0.206952            0.103554  0.026304    0.127100  1.227376
# 414            0.149364            0.103554  0.017951    0.120181  1.160562
# 124            0.176291            0.103554  0.020493    0.116245  1.122555
# 408            0.506252            0.103554  0.054112    0.106887  1.032185
# 34             0.841401            0.103554  0.089079    0.105870  1.022367
# 122            0.601505            0.103554  0.062931    0.104623  1.010326
# 676            0.231025            0.103554  0.024073    0.104199  1.006234
# 492            0.282387            0.103554  0.029053    0.102884  0.993536
# 246            0.386615            0.103554  0.037925    0.098094  0.947280
# 60             0.472944            0.103554  0.045655    0.096534  0.932207
# 8              0.158599            0.103554  0.014475    0.091266  0.881338
# 306            0.161193            0.103554  0.011258    0.069842  0.674454
# 82             0.184280            0.103554  0.012399    0.067286  0.649769
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 348               1.0  0.009494    1.037421       0.336855  0.111676
# 98                1.0  0.010004    1.033651       0.334533  0.113513
# 844               1.0  0.004659    1.030087       0.245510  0.089339
# 570               1.0  0.004873    1.026974       0.233597  0.092552
# 414               1.0  0.002483    1.018898       0.162641  0.076397
# 124               1.0  0.002237    1.014360       0.132541  0.079016
# 408               1.0  0.001687    1.003732       0.063152  0.097377
# 34                1.0  0.001949    1.002590       0.137943  0.104080
# 122               1.0  0.000643    1.001194       0.025647  0.098004
# 676               1.0  0.000149    1.000721       0.008057  0.077527
# 492               1.0 -0.000189    0.999254      -0.008985  0.081407
# 246               1.0 -0.002111    0.993947      -0.083185  0.083859
# 60                1.0 -0.003320    0.992230      -0.121250  0.086005
# 8                 1.0 -0.001949    0.986478      -0.137943  0.058442
# 306               1.0 -0.005434    0.963757      -0.365256  0.044413
# 82                1.0 -0.006683    0.961116      -0.397872  0.045018
#
#      certainty  kulczynski
# 348   0.036071    0.260580
# 98    0.032555    0.286058
# 844   0.029208    0.176342
# 570   0.026266    0.190554
# 414   0.018547    0.146764
# 124   0.014157    0.157070
# 408   0.003718    0.314716
# 34    0.002584    0.483045
# 122   0.001193    0.356169
# 676   0.000720    0.168332
# 492  -0.000747    0.191723
# 246  -0.006090    0.232163
# 60   -0.007831    0.268708
# 8    -0.013707    0.115523
# 306  -0.037606    0.089280
# 82   -0.040457    0.093513

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions22Part2 = complete[['events','Hitter_Types','impact_archetype']].copy()
display(transactions22Part2)
for col in transactions22Part2.columns:
    transactions22Part2[col] = transactions22Part2[col].astype(str)
    transactions22Part2[col] = col + "_" + transactions22Part2[col]
transactionListsPart2 = transactions22Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
# Out:
#          events               Hitter_Types  \
# 0        single           Balanced Hitters
# 1        single  Hitters With Good Contact
# 2          walk           Balanced Hitters
# 3      home_run              Power Hitters
# 4        single           Balanced Hitters
# ...         ...                        ...
# 20282  home_run              Power Hitters
# 20283    single           Balanced Hitters
# 20284    single           Balanced Hitters
# 20285      walk           Balanced Hitters
# 20286    double  Hitters With Good Contact
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3      Balanced Positive Arsenal (Mild Impact Gains)
# 4                   Four-Seam Aces (Elite FF Impact)
# ...                                              ...
# 20282               Four-Seam Aces (Elite FF Impact)
# 20283  Balanced Positive Arsenal (Mild Impact Gains)
# 20284  Balanced Positive Arsenal (Mild Impact Gains)
# 20285  Balanced Positive Arsenal (Mild Impact Gains)
# 20286  Balanced Positive Arsenal (Mild Impact Gains)
#
# [20287 rows x 3 columns]

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
cleanHR = clean[clean['consequents'].apply(lambda x: any('home_run' in item for item in x))]

display(cleanHR)
# Out:
#                                            antecedents        consequents  \
# 42                        (Hitter_Types_Power Hitters)  (events_home_run)
# 200  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 66   (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 116  (Hitter_Types_Balanced Hitters, impact_archety...  (events_home_run)
# 68   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_home_run)
# 110  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 6                      (Hitter_Types_Balanced Hitters)  (events_home_run)
# 64   (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 28            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 42             0.249618            0.097797  0.033420    0.133886  1.369027
# 200            0.134372            0.097797  0.016562    0.123258  1.260345
# 66             0.193572            0.097797  0.021837    0.112809  1.153504
# 116            0.105536            0.097797  0.010598    0.100420  1.026829
# 68             0.166018            0.097797  0.016464    0.099169  1.014029
# 110            0.285158            0.097797  0.028048    0.098358  1.005738
# 6              0.538522            0.097797  0.051757    0.096110  0.982752
# 64             0.532016            0.097797  0.051067    0.095988  0.981508
# 28             0.211860            0.097797  0.012619    0.059563  0.609045
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 42                1.0  0.009009    1.041668       0.359223  0.106436
# 200               1.0  0.003421    1.029040       0.238632  0.076818
# 66                1.0  0.002906    1.016921       0.165019  0.081017
# 116               1.0  0.000277    1.002917       0.029210  0.054987
# 68                1.0  0.000228    1.001523       0.016589  0.066560
# 110               1.0  0.000160    1.000622       0.007982  0.079028
# 6                 1.0 -0.000908    0.998134      -0.036638  0.088540
# 64                1.0 -0.000962    0.997999      -0.038701  0.088238
# 28                1.0 -0.008100    0.959344      -0.448874  0.042483
#
#      certainty  kulczynski
# 42    0.040002    0.237810
# 200   0.028221    0.146306
# 66    0.016639    0.168048
# 116   0.002908    0.104394
# 68    0.001521    0.133758
# 110   0.000622    0.192576
# 6    -0.001870    0.312672
# 64   -0.002005    0.309083
# 28   -0.042379    0.094297

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions22Part3 = complete[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
display(transactions22Part3)
for col in transactions22Part3.columns:
    transactions22Part3[col] = transactions22Part3[col].astype(str)
    transactions22Part3[col] = col + "_" + transactions22Part3[col]
transactionListsPart3 = transactions22Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
# Out:
#          events               Hitter_Types       Ball Preference  \
# 0        single           Balanced Hitters  Selective / Moderate
# 1        single  Hitters With Good Contact  Selective / Moderate
# 2          walk           Balanced Hitters  Selective / Moderate
# 3      home_run              Power Hitters  Selective / Moderate
# 4        single           Balanced Hitters  Selective / Moderate
# ...         ...                        ...                   ...
# 20282  home_run              Power Hitters  Selective / Moderate
# 20283    single           Balanced Hitters  Selective / Moderate
# 20284    single           Balanced Hitters  Selective / Moderate
# 20285      walk           Balanced Hitters  Selective / Moderate
# 20286    double  Hitters With Good Contact   Aggressive Fastball
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3      Balanced Positive Arsenal (Mild Impact Gains)
# 4                   Four-Seam Aces (Elite FF Impact)
# ...                                              ...
# 20282               Four-Seam Aces (Elite FF Impact)
# 20283  Balanced Positive Arsenal (Mild Impact Gains)
# 20284  Balanced Positive Arsenal (Mild Impact Gains)
# 20285  Balanced Positive Arsenal (Mild Impact Gains)
# 20286  Balanced Positive Arsenal (Mild Impact Gains)
#
# [20287 rows x 4 columns]

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)
cleansedDFHR = cleansedDF[cleansedDF['consequents'].apply(lambda x: any('home_run' in item for item in x))]

display(cleansedDFHR)
# Out:
#                                            antecedents        consequents  \
# 446  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 102                       (Hitter_Types_Power Hitters)  (events_home_run)
# 506  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 656  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 248  (Ball Preference_Aggressive Fastball, Hitter_T...  (events_home_run)
# 126  (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 42              (Ball Preference_Selective / Moderate)  (events_home_run)
# 500  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 908  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 362  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 574  (Hitter_Types_Balanced Hitters, impact_archety...  (events_home_run)
# 128  (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_home_run)
# 566  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 66                     (Hitter_Types_Balanced Hitters)  (events_home_run)
# 124  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 158  (Ball Preference_Aggressive Fastball, Hitter_T...  (events_home_run)
# 712  (Ball Preference_Aggressive Fastball, impact_a...  (events_home_run)
# 12               (Ball Preference_Aggressive Fastball)  (events_home_run)
# 308  (Ball Preference_Aggressive Fastball, impact_a...  (events_home_run)
# 88            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 446            0.114753            0.097797  0.017745    0.154639  1.581232
# 102            0.249618            0.097797  0.033420    0.133886  1.369027
# 506            0.093804            0.097797  0.011929    0.127168  1.300327
# 656            0.134372            0.097797  0.016562    0.123258  1.260345
# 248            0.134865            0.097797  0.015675    0.116228  1.188467
# 126            0.193572            0.097797  0.021837    0.112809  1.153504
# 42             0.466555            0.097797  0.052102    0.111675  1.141906
# 500            0.247942            0.097797  0.027653    0.111531  1.140436
# 908            0.149751            0.097797  0.016316    0.108953  1.114080
# 362            0.281905            0.097797  0.028836    0.102291  1.045952
# 574            0.105536            0.097797  0.010598    0.100420  1.026829
# 128            0.166018            0.097797  0.016464    0.099169  1.014029
# 566            0.285158            0.097797  0.028048    0.098358  1.005738
# 66             0.538522            0.097797  0.051757    0.096110  0.982752
# 124            0.532016            0.097797  0.051067    0.095988  0.981508
# 158            0.256618            0.097797  0.022921    0.089320  0.913324
# 712            0.135407            0.097797  0.011732    0.086640  0.885920
# 12             0.533445            0.097797  0.045694    0.085659  0.875888
# 308            0.284074            0.097797  0.023414    0.082422  0.842793
# 88             0.211860            0.097797  0.012619    0.059563  0.609045
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 446               1.0  0.006523    1.067241       0.415231  0.091093
# 102               1.0  0.009009    1.041668       0.359223  0.106436
# 506               1.0  0.002755    1.033650       0.254871  0.066392
# 656               1.0  0.003421    1.029040       0.238632  0.076818
# 248               1.0  0.002486    1.020855       0.183301  0.072240
# 126               1.0  0.002906    1.016921       0.165019  0.081017
# 42                1.0  0.006475    1.015623       0.232960  0.101713
# 500               1.0  0.003405    1.015458       0.163741  0.086936
# 908               1.0  0.001671    1.012521       0.120433  0.070561
# 362               1.0  0.001267    1.005006       0.061181  0.082186
# 574               1.0  0.000277    1.002917       0.029210  0.054987
# 128               1.0  0.000228    1.001523       0.016589  0.066560
# 566               1.0  0.000160    1.000622       0.007982  0.079028
# 66                1.0 -0.000908    0.998134      -0.036638  0.088540
# 124               1.0 -0.000962    0.997999      -0.038701  0.088238
# 158               1.0 -0.002175    0.990692      -0.113209  0.069145
# 712               1.0 -0.001511    0.987785      -0.129631  0.052971
# 12                1.0 -0.006475    0.986725      -0.232960  0.078037
# 308               1.0 -0.004367    0.983245      -0.206692  0.065319
# 88                1.0 -0.008100    0.959344      -0.448874  0.042483
#
#      certainty  kulczynski
# 446   0.063004    0.168045
# 102   0.040002    0.237810
# 506   0.032555    0.124572
# 656   0.028221    0.146306
# 248   0.020429    0.138255
# 126   0.016639    0.168048
# 42    0.015382    0.322218
# 500   0.015223    0.197146
# 908   0.012366    0.137894
# 362   0.004981    0.198575
# 574   0.002908    0.104394
# 128   0.001521    0.133758
# 566   0.000622    0.192576
# 66   -0.001870    0.312672
# 124  -0.002005    0.309083
# 158  -0.009395    0.161848
# 712  -0.012366    0.103300
# 12   -0.013453    0.276448
# 308  -0.017041    0.160919
# 88   -0.042379    0.094297

# %%
#2023 Data
transactions23 = complete2[['events','Swinging Tendencies','quality_archetype']].copy()
for col in transactions23.columns:
    transactions23[col] = transactions23[col].astype(str)
    transactions23[col] = col + "_" + transactions23[col]
transactionLists = transactions23.values.tolist()
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
firstCleaned.sort_values(by='confidence', ascending=False, inplace=True)
firstCleanedHR = firstCleaned[firstCleaned['consequents'].apply(lambda x: any('home_run' in item for item in x))]


display(firstCleanedHR)
# Out:
#                                            antecedents        consequents  \
# 170  (quality_archetype_League-Average Pitch Qualit...  (events_home_run)
# 124  (quality_archetype_League-Average Pitch Qualit...  (events_home_run)
# 24                      (Swinging Tendencies_Balanced)  (events_home_run)
# 80   (quality_archetype_Four-Seam Aces (Elite FF Qu...  (events_home_run)
# 3                     (Swinging Tendencies_Aggressive)  (events_home_run)
# 84    (quality_archetype_Weak Fastball Group (Bad FF))  (events_home_run)
# 82    (quality_archetype_League-Average Pitch Quality)  (events_home_run)
# 48                     (Swinging Tendencies_Selective)  (events_home_run)
# 212  (Swinging Tendencies_Selective, quality_archet...  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 170            0.121059            0.106499  0.015042    0.124253  1.166710
# 124            0.125976            0.106499  0.015524    0.123230  1.157101
# 24             0.308794            0.106499  0.037364    0.120999  1.136155
# 80             0.111175            0.106499  0.012921    0.116219  1.091265
# 3              0.312024            0.106499  0.036159    0.115884  1.088122
# 84             0.161508            0.106499  0.017886    0.110746  1.039882
# 82             0.394562            0.106499  0.042474    0.107649  1.010800
# 48             0.379182            0.106499  0.032977    0.086968  0.816605
# 212            0.147527            0.106499  0.011908    0.080719  0.757932
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 170               1.0  0.002149    1.020273       0.162569  0.070780
# 124               1.0  0.002108    1.019083       0.155341  0.071556
# 24                1.0  0.004478    1.016496       0.173375  0.098865
# 80                1.0  0.001081    1.010998       0.094094  0.063103
# 3                 1.0  0.002928    1.010615       0.117716  0.094566
# 84                1.0  0.000686    1.004776       0.045740  0.071511
# 82                1.0  0.000454    1.001289       0.017648  0.092620
# 48                1.0 -0.007406    0.978608      -0.265651  0.072843
# 212               1.0 -0.003803    0.971956      -0.272542  0.049184
#
#      certainty  kulczynski
# 170   0.019871    0.132747
# 124   0.018725    0.134499
# 24    0.016229    0.235918
# 80    0.010878    0.118770
# 3     0.010504    0.227702
# 84    0.004754    0.139348
# 82    0.001287    0.253236
# 48   -0.021859    0.198305
# 212  -0.028853    0.096267

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions23Part2 = complete2[['events','Hitter_Types','impact_archetype']].copy()
for col in transactions23Part2.columns:
    transactions23Part2[col] = transactions23Part2[col].astype(str)
    transactions23Part2[col] = col + "_" + transactions23Part2[col]
transactionListsPart2 = transactions23Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
cleanHR = clean[clean['consequents'].apply(lambda x: any('home_run' in item for item in x))]

display(cleanHR)
# Out:
#                                            antecedents        consequents  \
# 196  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 40                        (Hitter_Types_Power Hitters)  (events_home_run)
# 74   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_home_run)
# 70   (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 72   (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 112  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 4                      (Hitter_Types_Balanced Hitters)  (events_home_run)
# 24            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 196            0.189953            0.106499  0.026709    0.140609  1.320287
# 40             0.329862            0.106499  0.045174    0.136948  1.285913
# 74             0.111416            0.106499  0.012680    0.113804  1.068589
# 70             0.574728            0.106499  0.062530    0.108800  1.021603
# 72             0.155241            0.106499  0.016874    0.108696  1.020627
# 112            0.285508            0.106499  0.029264    0.102499  0.962443
# 4              0.495565            0.106499  0.049899    0.100691  0.945463
# 24             0.174573            0.106499  0.011426    0.065452  0.614575
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 196               1.0  0.006479    1.039691       0.299475  0.099017
# 40                1.0  0.010044    1.035281       0.331786  0.115479
# 74                1.0  0.000814    1.008243       0.072235  0.061781
# 70                1.0  0.001322    1.002582       0.049724  0.101068
# 72                1.0  0.000341    1.002465       0.023924  0.068911
# 112               1.0 -0.001142    0.995543      -0.051787  0.080675
# 4                 1.0 -0.002878    0.993542      -0.102617  0.090369
# 24                1.0 -0.007166    0.956078      -0.431747  0.042374
#
#      certainty  kulczynski
# 196   0.038176    0.195701
# 40    0.034079    0.280561
# 74    0.008175    0.116431
# 70    0.002575    0.347972
# 72    0.002459    0.133569
# 112  -0.004476    0.188642
# 4    -0.006500    0.284614
# 24   -0.045940    0.086370

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions23Part3 = complete2[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
for col in transactions23Part3.columns:
    transactions23Part3[col] = transactions23Part3[col].astype(str)
    transactions23Part3[col] = col + "_" + transactions23Part3[col]
transactionListsPart3 = transactions23Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)
cleansedDFHR = cleansedDF[cleansedDF['consequents'].apply(lambda x: any('home_run' in item for item in x))]


display(cleansedDFHR)
# Out:
#                                            antecedents        consequents  \
# 630  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 882  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 96                        (Hitter_Types_Power Hitters)  (events_home_run)
# 384  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 456  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 462  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 130  (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_home_run)
# 36              (Ball Preference_Selective / Moderate)  (events_home_run)
# 126  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 128  (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 742  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 288  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 546  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 60                     (Hitter_Types_Balanced Hitters)  (events_home_run)
# 8                (Ball Preference_Aggressive Fastball)  (events_home_run)
# 246  (Ball Preference_Aggressive Fastball, impact_a...  (events_home_run)
# 162  (Ball Preference_Aggressive Fastball, Hitter_T...  (events_home_run)
# 80            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 630            0.189953            0.106499  0.026709    0.140609  1.320287
# 882            0.156398            0.106499  0.021743    0.139026  1.305421
# 96             0.329862            0.106499  0.045174    0.136948  1.285913
# 384            0.271960            0.106499  0.036882    0.135614  1.273387
# 456            0.434047            0.106499  0.050092    0.115406  1.083635
# 462            0.118889            0.106499  0.013644    0.114761  1.077577
# 130            0.111416            0.106499  0.012680    0.113804  1.068589
# 36             0.756533            0.106499  0.084756    0.112032  1.051951
# 126            0.574728            0.106499  0.062530    0.108800  1.021603
# 128            0.155241            0.106499  0.016874    0.108696  1.020627
# 742            0.216180            0.106499  0.023479    0.108608  1.019808
# 288            0.377157            0.106499  0.039485    0.104691  0.983027
# 546            0.285508            0.106499  0.029264    0.102499  0.962443
# 60             0.495565            0.106499  0.049899    0.100691  0.945463
# 8              0.243467            0.106499  0.021743    0.089307  0.838571
# 246            0.140681            0.106499  0.012439    0.088417  0.830213
# 162            0.118407            0.106499  0.010414    0.087948  0.825810
# 80             0.174573            0.106499  0.011426    0.065452  0.614575
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 630               1.0  0.006479    1.039691       0.299475  0.099017
# 882               1.0  0.005087    1.037779       0.277339  0.090164
# 96                1.0  0.010044    1.035281       0.331786  0.115479
# 384               1.0  0.007918    1.033683       0.294891  0.107975
# 456               1.0  0.003866    1.010069       0.136373  0.102133
# 462               1.0  0.000982    1.009333       0.081706  0.064435
# 130               1.0  0.000814    1.008243       0.072235  0.061781
# 36                1.0  0.004186    1.006231       0.202842  0.108902
# 126               1.0  0.001322    1.002582       0.049724  0.101068
# 128               1.0  0.000341    1.002465       0.023924  0.068911
# 742               1.0  0.000456    1.002367       0.024780  0.078472
# 288               1.0 -0.000682    0.997981      -0.026973  0.088896
# 546               1.0 -0.001142    0.995543      -0.051787  0.080675
# 60                1.0 -0.002878    0.993542      -0.102617  0.090369
# 8                 1.0 -0.004186    0.981122      -0.202842  0.066246
# 246               1.0 -0.002544    0.980164      -0.192240  0.052988
# 162               1.0 -0.002197    0.979660      -0.193068  0.048550
# 80                1.0 -0.007166    0.956078      -0.431747  0.042374
#
#      certainty  kulczynski
# 630   0.038176    0.195701
# 882   0.036404    0.171595
# 96    0.034079    0.280561
# 384   0.032586    0.240962
# 456   0.009969    0.292877
# 462   0.009247    0.121437
# 130   0.008175    0.116431
# 36    0.006192    0.453933
# 126   0.002575    0.347972
# 128   0.002459    0.133569
# 742   0.002361    0.164535
# 288  -0.002023    0.237724
# 546  -0.004476    0.188642
# 60   -0.006500    0.284614
# 8    -0.019241    0.146736
# 246  -0.020237    0.102606
# 162  -0.020762    0.092865
# 80   -0.045940    0.086370

# %%
#2024 Data
transactions24 = complete3[['events','Swinging Tendencies','quality_archetype']].copy()
for col in transactions24.columns:
    transactions24[col] = transactions24[col].astype(str)
    transactions24[col] = col + "_" + transactions24[col]
transactionLists = transactions24.values.tolist()
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
firstCleanedHR = firstCleaned[firstCleaned['consequents'].apply(lambda x: any('home_run' in item for item in x))]

display(firstCleanedHR)
# Out:
#                                            antecedents        consequents  \
# 182  (quality_archetype_League-Average Pitch Qualit...  (events_home_run)
# 32                      (Swinging Tendencies_Balanced)  (events_home_run)
# 130  (quality_archetype_League-Average Pitch Qualit...  (events_home_run)
# 86    (quality_archetype_Weak Fastball Group (Bad FF))  (events_home_run)
# 5                     (Swinging Tendencies_Aggressive)  (events_home_run)
# 84    (quality_archetype_League-Average Pitch Quality)  (events_home_run)
# 56                     (Swinging Tendencies_Selective)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 182            0.154916            0.103554  0.018833    0.121567  1.173953
# 32             0.369442            0.103554  0.043684    0.118242  1.141839
# 130            0.141427            0.103554  0.016342    0.115554  1.115883
# 86             0.150039            0.103554  0.017276    0.115145  1.111936
# 5              0.338833            0.103554  0.037458    0.110550  1.067558
# 84             0.419922            0.103554  0.044099    0.105016  1.014121
# 56             0.291725            0.103554  0.022412    0.076827  0.741907
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 182               1.0  0.002791    1.020506       0.175340  0.078588
# 32                1.0  0.005426    1.016658       0.197000  0.101752
# 130               1.0  0.001697    1.013568       0.120955  0.071477
# 86                1.0  0.001739    1.013100       0.118438  0.073106
# 5                 1.0  0.002370    1.007865       0.095713  0.092505
# 84                1.0  0.000614    1.001634       0.024004  0.091991
# 56                1.0 -0.007797    0.971049      -0.329382  0.060109
#
#      certainty  kulczynski
# 182   0.020094    0.151716
# 32    0.016385    0.270043
# 130   0.013386    0.136685
# 86    0.012930    0.140989
# 5     0.007804    0.236137
# 84    0.001631    0.265434
# 56   -0.029814    0.146630

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions24Part2 = complete3[['events','Hitter_Types','impact_archetype']].copy()
for col in transactions24Part2.columns:
    transactions24Part2[col] = transactions24Part2[col].astype(str)
    transactions24Part2[col] = col + "_" + transactions24Part2[col]
transactionListsPart2 = transactions24Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
cleanHR = clean[clean['consequents'].apply(lambda x: any('home_run' in item for item in x))]

display(cleanHR)
# Out:
#                                            antecedents        consequents  \
# 42                        (Hitter_Types_Power Hitters)  (events_home_run)
# 184  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 68   (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 66   (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 106  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 4                      (Hitter_Types_Balanced Hitters)  (events_home_run)
# 26            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 42             0.342776            0.103554  0.045499    0.132738  1.281826
# 184            0.206952            0.103554  0.026304    0.127100  1.227376
# 68             0.176291            0.103554  0.020493    0.116245  1.122555
# 66             0.601505            0.103554  0.062931    0.104623  1.010326
# 106            0.282387            0.103554  0.029053    0.102884  0.993536
# 4              0.472944            0.103554  0.045655    0.096534  0.932207
# 26             0.184280            0.103554  0.012399    0.067286  0.649769
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 42                1.0  0.010004    1.033651       0.334533  0.113513
# 184               1.0  0.004873    1.026974       0.233597  0.092552
# 68                1.0  0.002237    1.014360       0.132541  0.079016
# 66                1.0  0.000643    1.001194       0.025647  0.098004
# 106               1.0 -0.000189    0.999254      -0.008985  0.081407
# 4                 1.0 -0.003320    0.992230      -0.121250  0.086005
# 26                1.0 -0.006683    0.961116      -0.397872  0.045018
#
#      certainty  kulczynski
# 42    0.032555    0.286058
# 184   0.026266    0.190554
# 68    0.014157    0.157070
# 66    0.001193    0.356169
# 106  -0.000747    0.191723
# 4    -0.007831    0.268708
# 26   -0.040457    0.093513

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions24Part3 = complete3[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
for col in transactions24Part3.columns:
    transactions24Part3[col] = transactions24Part3[col].astype(str)
    transactions24Part3[col] = col + "_" + transactions24Part3[col]
transactionListsPart3 = transactions24Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.01, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.01)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)

cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)
cleansedDFHR = cleansedDF[cleansedDF['consequents'].apply(lambda x: any('home_run' in item for item in x))]
display(cleansedDFHR)
# Out:
#                                            antecedents        consequents  \
# 348  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 98                        (Hitter_Types_Power Hitters)  (events_home_run)
# 844  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 570  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 414  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 124  (impact_archetype_FF Liability Pitchers (Bad F...  (events_home_run)
# 408  (Ball Preference_Selective / Moderate, impact_...  (events_home_run)
# 34              (Ball Preference_Selective / Moderate)  (events_home_run)
# 122  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 676  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 492  (impact_archetype_Balanced Positive Arsenal (M...  (events_home_run)
# 246  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 60                     (Hitter_Types_Balanced Hitters)  (events_home_run)
# 8                (Ball Preference_Aggressive Fastball)  (events_home_run)
# 306  (Ball Preference_Selective / Moderate, Hitter_...  (events_home_run)
# 82            (Hitter_Types_Hitters With Good Contact)  (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 348            0.293593            0.103554  0.039896    0.135890  1.312262
# 98             0.342776            0.103554  0.045499    0.132738  1.281826
# 844            0.177951            0.103554  0.023087    0.129738  1.252852
# 570            0.206952            0.103554  0.026304    0.127100  1.227376
# 414            0.149364            0.103554  0.017951    0.120181  1.160562
# 124            0.176291            0.103554  0.020493    0.116245  1.122555
# 408            0.506252            0.103554  0.054112    0.106887  1.032185
# 34             0.841401            0.103554  0.089079    0.105870  1.022367
# 122            0.601505            0.103554  0.062931    0.104623  1.010326
# 676            0.231025            0.103554  0.024073    0.104199  1.006234
# 492            0.282387            0.103554  0.029053    0.102884  0.993536
# 246            0.386615            0.103554  0.037925    0.098094  0.947280
# 60             0.472944            0.103554  0.045655    0.096534  0.932207
# 8              0.158599            0.103554  0.014475    0.091266  0.881338
# 306            0.161193            0.103554  0.011258    0.069842  0.674454
# 82             0.184280            0.103554  0.012399    0.067286  0.649769
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 348               1.0  0.009494    1.037421       0.336855  0.111676
# 98                1.0  0.010004    1.033651       0.334533  0.113513
# 844               1.0  0.004659    1.030087       0.245510  0.089339
# 570               1.0  0.004873    1.026974       0.233597  0.092552
# 414               1.0  0.002483    1.018898       0.162641  0.076397
# 124               1.0  0.002237    1.014360       0.132541  0.079016
# 408               1.0  0.001687    1.003732       0.063152  0.097377
# 34                1.0  0.001949    1.002590       0.137943  0.104080
# 122               1.0  0.000643    1.001194       0.025647  0.098004
# 676               1.0  0.000149    1.000721       0.008057  0.077527
# 492               1.0 -0.000189    0.999254      -0.008985  0.081407
# 246               1.0 -0.002111    0.993947      -0.083185  0.083859
# 60                1.0 -0.003320    0.992230      -0.121250  0.086005
# 8                 1.0 -0.001949    0.986478      -0.137943  0.058442
# 306               1.0 -0.005434    0.963757      -0.365256  0.044413
# 82                1.0 -0.006683    0.961116      -0.397872  0.045018
#
#      certainty  kulczynski
# 348   0.036071    0.260580
# 98    0.032555    0.286058
# 844   0.029208    0.176342
# 570   0.026266    0.190554
# 414   0.018547    0.146764
# 124   0.014157    0.157070
# 408   0.003718    0.314716
# 34    0.002584    0.483045
# 122   0.001193    0.356169
# 676   0.000720    0.168332
# 492  -0.000747    0.191723
# 246  -0.006090    0.232163
# 60   -0.007831    0.268708
# 8    -0.013707    0.115523
# 306  -0.037606    0.089280
# 82   -0.040457    0.093513
