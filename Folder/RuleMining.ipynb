# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\aidhe\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\aidhe\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aidhe\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aidhe\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aidhe\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aidhe\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\aidhe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
import pandas as pd

# %%
Csv = pd.read_csv('BatterInformation.csv')
filteredCSV = Csv[(Csv['year'] >= 2022) & (Csv['year'] < 2025)]

# %%
Pitchers = pd.read_csv('Pitchers_With_Clusters.csv')
filteredPitchers = Pitchers[(Pitchers['year'] >= 2022) & (Pitchers['year'] < 2025)]

# %%
display(filteredPitchers)
# Out:
#       player_id  year last_name, first_name  kmeans_quality_cluster  \
# 4        425794  2022      Wainwright, Adam                       1
# 5        425794  2023      Wainwright, Adam                       5
# 9        425844  2022         Greinke, Zack                       3
# 10       425844  2023         Greinke, Zack                       3
# 17       434378  2022     Verlander, Justin                       7
# ...         ...   ...                   ...                     ...
# 2208     695243  2024         Miller, Mason                       2
# 2212     700249  2024          Povich, Cade                       1
# 2215     701581  2024          Festa, David                       3
# 2220     806185  2024      Birdsong, Hayden                       3
# 2223     808967  2024   Yamamoto, Yoshinobu                       1
#
#                       quality_archetype  impact_cluster  \
# 4          League-Average Pitch Quality               2
# 5              Sinkers Get Hit (Bad SI)               1
# 9          Weak Fastball Group (Bad FF)               0
# 10         Weak Fastball Group (Bad FF)               0
# 17               Slider Aces (Elite SL)               5
# ...                                 ...             ...
# 2208  Four-Seam Aces (Elite FF Quality)               5
# 2212       League-Average Pitch Quality               2
# 2215       Weak Fastball Group (Bad FF)               0
# 2220       Weak Fastball Group (Bad FF)               0
# 2223       League-Average Pitch Quality               2
#
#                                      impact_archetype
# 4       Balanced Positive Arsenal (Mild Impact Gains)
# 5     Sinker Liability Pitchers (Sinker Gets Crushed)
# 9         FF Liability Pitchers (Bad Fastball Impact)
# 10        FF Liability Pitchers (Bad Fastball Impact)
# 17                   Four-Seam Aces (Elite FF Impact)
# ...                                               ...
# 2208                 Four-Seam Aces (Elite FF Impact)
# 2212    Balanced Positive Arsenal (Mild Impact Gains)
# 2215      FF Liability Pitchers (Bad Fastball Impact)
# 2220      FF Liability Pitchers (Bad Fastball Impact)
# 2223    Balanced Positive Arsenal (Mild Impact Gains)
#
# [923 rows x 7 columns]

# %%
display(filteredCSV)
# Out:
#      last_name, first_name  player_id  year  Cluster_Group  \
# 982           Cruz, Nelson     443558  2022              2
# 983      Blackmon, Charlie     453568  2022              0
# 984      McCutchen, Andrew     457705  2022              2
# 985         Turner, Justin     457759  2022              2
# 986          Andrus, Elvis     462101  2022              0
# ...                    ...        ...   ...            ...
# 1370      Chourio, Jackson     694192  2024              2
# 1371       Schanuel, Nolan     694384  2024              0
# 1372       Langford, Wyatt     694671  2024              2
# 1373          Young, Jacob     696285  2024              0
# 1374      Merrill, Jackson     701538  2024              2
#
#                    Hitter_Types  Cluster_Group.1       Ball Preference  \
# 982            Balanced Hitters                2   Aggressive Fastball
# 983   Hitters With Good Contact                2   Aggressive Fastball
# 984            Balanced Hitters                2   Aggressive Fastball
# 985            Balanced Hitters                2   Aggressive Fastball
# 986   Hitters With Good Contact                0  Selective / Moderate
# ...                         ...              ...                   ...
# 1370           Balanced Hitters                0  Selective / Moderate
# 1371  Hitters With Good Contact                0  Selective / Moderate
# 1372           Balanced Hitters                0  Selective / Moderate
# 1373  Hitters With Good Contact                0  Selective / Moderate
# 1374           Balanced Hitters                0  Selective / Moderate
#
#       Cluster_Group.2 Swinging Tendencies
# 982                 1            Balanced
# 983                 0          Aggressive
# 984                 1            Balanced
# 985                 2           Selective
# 986                 2           Selective
# ...               ...                 ...
# 1370                0          Aggressive
# 1371                2           Selective
# 1372                1            Balanced
# 1373                2           Selective
# 1374                0          Aggressive
#
# [393 rows x 9 columns]

# %%
#2022 Data
Events = pd.read_csv('statcast_pitch_by_pitch_2022.csv')
CondensedEvent = Events[['game_date','batter','pitcher','events','pitch_name','year']].copy()

# %%
merged = CondensedEvent.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean = merged.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete = df_clean.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete)
# Out:
#         game_date  batter  pitcher     events       pitch_name  year  \
# 0      2022-11-05  663656   502085  field_out    Knuckle Curve  2022
# 1      2022-11-05  608324   502085     single    Knuckle Curve  2022
# 2      2022-11-05  670541   502085  strikeout    Knuckle Curve  2022
# 3      2022-11-05  656941   650556  strikeout  4-Seam Fastball  2022
# 4      2022-11-05  665161   621107  strikeout        Curveball  2022
# ...           ...     ...      ...        ...              ...   ...
# 60054  2022-03-18  650402   640444       walk         Changeup  2022
# 60055  2022-03-18  643396   640444     double           Sinker  2022
# 60056  2022-03-18  571448   434378  field_out           Slider  2022
# 60057  2022-03-18  502671   434378  strikeout           Slider  2022
# 60058  2022-03-18  669242   434378  field_out  4-Seam Fastball  2022
#
#       last_name, first_name_x  player_id_x  Cluster_Group  \
# 0                Tucker, Kyle     663656.0            2.0
# 1               Bregman, Alex     608324.0            2.0
# 2             Alvarez, Yordan     670541.0            1.0
# 3             Schwarber, Kyle     656941.0            1.0
# 4                Peña, Jeremy     665161.0            2.0
# ...                       ...          ...            ...
# 60054         Torres, Gleyber     650402.0            2.0
# 60055     Kiner-Falefa, Isiah     643396.0            0.0
# 60056          Arenado, Nolan     571448.0            2.0
# 60057       Goldschmidt, Paul     502671.0            1.0
# 60058            Edman, Tommy     669242.0            2.0
#
#                     Hitter_Types  Cluster_Group.1       Ball Preference  \
# 0               Balanced Hitters              0.0  Selective / Moderate
# 1               Balanced Hitters              0.0  Selective / Moderate
# 2                  Power Hitters              0.0  Selective / Moderate
# 3                  Power Hitters              0.0  Selective / Moderate
# 4               Balanced Hitters              0.0  Selective / Moderate
# ...                          ...              ...                   ...
# 60054           Balanced Hitters              0.0  Selective / Moderate
# 60055  Hitters With Good Contact              2.0   Aggressive Fastball
# 60056           Balanced Hitters              2.0   Aggressive Fastball
# 60057              Power Hitters              2.0   Aggressive Fastball
# 60058           Balanced Hitters              0.0  Selective / Moderate
#
#        Cluster_Group.2 Swinging Tendencies  player_id_y  \
# 0                  0.0          Aggressive       502085
# 1                  2.0           Selective       502085
# 2                  1.0            Balanced       502085
# 3                  1.0            Balanced       650556
# 4                  0.0          Aggressive       621107
# ...                ...                 ...          ...
# 60054              1.0            Balanced       640444
# 60055              2.0           Selective       640444
# 60056              2.0           Selective       434378
# 60057              1.0            Balanced       434378
# 60058              2.0           Selective       434378
#
#       last_name, first_name_y  kmeans_quality_cluster  \
# 0            Robertson, David                       1
# 1            Robertson, David                       1
# 2            Robertson, David                       1
# 3                Abreu, Bryan                       7
# 4                 Eflin, Zach                       0
# ...                       ...                     ...
# 60054              Crowe, Wil                       6
# 60055              Crowe, Wil                       6
# 60056       Verlander, Justin                       7
# 60057       Verlander, Justin                       7
# 60058       Verlander, Justin                       7
#
#                               quality_archetype  impact_cluster  \
# 0                  League-Average Pitch Quality               2
# 1                  League-Average Pitch Quality               2
# 2                  League-Average Pitch Quality               2
# 3                        Slider Aces (Elite SL)               4
# 4      Fastball Generalists (Good FF + Good SI)               2
# ...                                         ...             ...
# 60054         Weak Breaking Ball Group (Bad SL)               2
# 60055         Weak Breaking Ball Group (Bad SL)               2
# 60056                    Slider Aces (Elite SL)               5
# 60057                    Slider Aces (Elite SL)               5
# 60058                    Slider Aces (Elite SL)               5
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3                  Slider Aces (Elite Slider Impact)
# 4      Balanced Positive Arsenal (Mild Impact Gains)
# ...                                              ...
# 60054  Balanced Positive Arsenal (Mild Impact Gains)
# 60055  Balanced Positive Arsenal (Mild Impact Gains)
# 60056               Four-Seam Aces (Elite FF Impact)
# 60057               Four-Seam Aces (Elite FF Impact)
# 60058               Four-Seam Aces (Elite FF Impact)
#
# [60059 rows x 20 columns]

# %%
#2023
Events2023 = pd.read_csv('statcast_pitch_by_pitch_2023.csv')
CondensedEvent2023 = Events2023[['game_date','batter','pitcher','events','pitch_name','year']].copy()
display(CondensedEvent2023)
# Out:
#          game_date  batter  pitcher     events       pitch_name  year
# 0       2023-11-01  606466   622250  strikeout        Curveball  2023
# 1       2023-11-01  606466   622250        NaN  4-Seam Fastball  2023
# 2       2023-11-01  606466   622250        NaN        Curveball  2023
# 3       2023-11-01  606466   622250        NaN  4-Seam Fastball  2023
# 4       2023-11-01  606466   622250        NaN  4-Seam Fastball  2023
# ...            ...     ...      ...        ...              ...   ...
# 774033  2023-03-15  679845   641540  field_out              NaN  2023
# 774034  2023-03-15  668472   641540  strikeout              NaN  2023
# 774035  2023-03-15  668472   641540        NaN              NaN  2023
# 774036  2023-03-15  668472   641540        NaN              NaN  2023
# 774037  2023-03-15  681987   641540     double              NaN  2023
#
# [774038 rows x 6 columns]

# %%
merged2 = CondensedEvent2023.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean2 = merged2.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete2 = df_clean2.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete2)
# Out:
#         game_date  batter  pitcher     events       pitch_name  year  \
# 0      2023-11-01  608369   623149     single          Sweeper  2023
# 1      2023-11-01  543760   623149   home_run  4-Seam Fastball  2023
# 2      2023-11-01  665750   623149  strikeout  4-Seam Fastball  2023
# 3      2023-11-01  663993   623149     single  4-Seam Fastball  2023
# 4      2023-11-01  673962   623149     single  4-Seam Fastball  2023
# ...           ...     ...      ...        ...              ...   ...
# 60564  2023-03-15  668804   670950  field_out         Changeup  2023
# 60565  2023-03-15  669261   592332       walk     Split-Finger  2023
# 60566  2023-03-15  668804   592332  strikeout     Split-Finger  2023
# 60567  2023-03-15  669261   592332       walk     Split-Finger  2023
# 60568  2023-03-15  668804   592332  strikeout     Split-Finger  2023
#
#       last_name, first_name_x  player_id_x  Cluster_Group      Hitter_Types  \
# 0               Seager, Corey     608369.0            1.0     Power Hitters
# 1              Semien, Marcus     543760.0            2.0  Balanced Hitters
# 2              Taveras, Leody     665750.0            2.0  Balanced Hitters
# 3             Lowe, Nathaniel     663993.0            2.0  Balanced Hitters
# 4                  Jung, Josh     673962.0            1.0     Power Hitters
# ...                       ...          ...            ...               ...
# 60564         Reynolds, Bryan     668804.0            2.0  Balanced Hitters
# 60565          Suwinski, Jack     669261.0            1.0     Power Hitters
# 60566         Reynolds, Bryan     668804.0            2.0  Balanced Hitters
# 60567          Suwinski, Jack     669261.0            1.0     Power Hitters
# 60568         Reynolds, Bryan     668804.0            2.0  Balanced Hitters
#
#        Cluster_Group.1       Ball Preference  Cluster_Group.2  \
# 0                  0.0  Selective / Moderate              0.0
# 1                  0.0  Selective / Moderate              2.0
# 2                  0.0  Selective / Moderate              0.0
# 3                  2.0   Aggressive Fastball              1.0
# 4                  0.0  Selective / Moderate              0.0
# ...                ...                   ...              ...
# 60564              0.0  Selective / Moderate              1.0
# 60565              0.0  Selective / Moderate              1.0
# 60566              0.0  Selective / Moderate              1.0
# 60567              0.0  Selective / Moderate              1.0
# 60568              0.0  Selective / Moderate              1.0
#
#       Swinging Tendencies  player_id_y last_name, first_name_y  \
# 0              Aggressive       623149            Sewald, Paul
# 1               Selective       623149            Sewald, Paul
# 2              Aggressive       623149            Sewald, Paul
# 3                Balanced       623149            Sewald, Paul
# 4              Aggressive       623149            Sewald, Paul
# ...                   ...          ...                     ...
# 60564            Balanced       670950        Richards, Trevor
# 60565            Balanced       592332          Gausman, Kevin
# 60566            Balanced       592332          Gausman, Kevin
# 60567            Balanced       592332          Gausman, Kevin
# 60568            Balanced       592332          Gausman, Kevin
#
#        kmeans_quality_cluster                  quality_archetype  \
# 0                           2  Four-Seam Aces (Elite FF Quality)
# 1                           2  Four-Seam Aces (Elite FF Quality)
# 2                           2  Four-Seam Aces (Elite FF Quality)
# 3                           2  Four-Seam Aces (Elite FF Quality)
# 4                           2  Four-Seam Aces (Elite FF Quality)
# ...                       ...                                ...
# 60564                       8    Changeup Specialists (Elite CH)
# 60565                       1       League-Average Pitch Quality
# 60566                       1       League-Average Pitch Quality
# 60567                       1       League-Average Pitch Quality
# 60568                       1       League-Average Pitch Quality
#
#        impact_cluster                               impact_archetype
# 0                   5               Four-Seam Aces (Elite FF Impact)
# 1                   5               Four-Seam Aces (Elite FF Impact)
# 2                   5               Four-Seam Aces (Elite FF Impact)
# 3                   5               Four-Seam Aces (Elite FF Impact)
# 4                   5               Four-Seam Aces (Elite FF Impact)
# ...               ...                                            ...
# 60564               2  Balanced Positive Arsenal (Mild Impact Gains)
# 60565               2  Balanced Positive Arsenal (Mild Impact Gains)
# 60566               2  Balanced Positive Arsenal (Mild Impact Gains)
# 60567               2  Balanced Positive Arsenal (Mild Impact Gains)
# 60568               2  Balanced Positive Arsenal (Mild Impact Gains)
#
# [60569 rows x 20 columns]

# %%
#2024
Events2024 = pd.read_csv('statcast_pitch_by_pitch_2024.csv')
CondensedEvent2024 = Events2024[['game_date','batter','pitcher','events','pitch_name','year']].copy()
display(CondensedEvent2024)
# Out:
#          game_date  batter  pitcher     events     pitch_name  year
# 0       2024-10-30  657077   621111  strikeout  Knuckle Curve  2024
# 1       2024-10-30  657077   621111        NaN  Knuckle Curve  2024
# 2       2024-10-30  657077   621111        NaN         Cutter  2024
# 3       2024-10-30  657077   621111        NaN  Knuckle Curve  2024
# 4       2024-10-30  669224   621111  strikeout  Knuckle Curve  2024
# ...            ...     ...      ...        ...            ...   ...
# 760243  2024-03-15  666310   663903        NaN            NaN  2024
# 760244  2024-03-15  666310   663903        NaN            NaN  2024
# 760245  2024-03-15  608070   663903     double            NaN  2024
# 760246  2024-03-15  665926   663903  field_out            NaN  2024
# 760247  2024-03-15  680757   663903  field_out            NaN  2024
#
# [760248 rows x 6 columns]

# %%
merged3 = CondensedEvent2024.merge(filteredCSV, left_on= ["batter",'year'], right_on=["player_id",'year'], how="left")
df_clean3 = merged3.dropna(subset=['pitch_name', 'events', 'Hitter_Types'])
complete3 = df_clean3.merge(filteredPitchers,left_on = ['pitcher','year'], right_on = ['player_id','year'])

# %%
display(complete3)
# Out:
#         game_date  batter  pitcher          events       pitch_name  year  \
# 0      2024-10-30  606192   596133          single  4-Seam Fastball  2024
# 1      2024-10-30  518692   596133       strikeout         Changeup  2024
# 2      2024-10-30  605141   596133         sac_fly  4-Seam Fastball  2024
# 3      2024-10-30  660271   596133  catcher_interf         Changeup  2024
# 4      2024-10-30  669257   592454            walk         Changeup  2024
# ...           ...     ...      ...             ...              ...   ...
# 57394  2024-03-15  571448   677960       field_out  4-Seam Fastball  2024
# 57395  2024-03-15  502671   677960       field_out  4-Seam Fastball  2024
# 57396  2024-03-15  669394   571927       force_out         Changeup  2024
# 57397  2024-03-15  605137   571927            walk           Sinker  2024
# 57398  2024-03-15  650333   571927       field_out           Sinker  2024
#
#       last_name, first_name_x  player_id_x  Cluster_Group  \
# 0          Hernández, Teoscar     606192.0            1.0
# 1            Freeman, Freddie     518692.0            2.0
# 2               Betts, Mookie     605141.0            2.0
# 3              Ohtani, Shohei     660271.0            1.0
# 4                 Smith, Will     669257.0            2.0
# ...                       ...          ...            ...
# 57394          Arenado, Nolan     571448.0            0.0
# 57395       Goldschmidt, Paul     502671.0            1.0
# 57396            Burger, Jake     669394.0            1.0
# 57397              Bell, Josh     605137.0            2.0
# 57398            Arraez, Luis     650333.0            0.0
#
#                     Hitter_Types  Cluster_Group.1       Ball Preference  \
# 0                  Power Hitters              0.0  Selective / Moderate
# 1               Balanced Hitters              0.0  Selective / Moderate
# 2               Balanced Hitters              0.0  Selective / Moderate
# 3                  Power Hitters              0.0  Selective / Moderate
# 4               Balanced Hitters              2.0   Aggressive Fastball
# ...                          ...              ...                   ...
# 57394  Hitters With Good Contact              0.0  Selective / Moderate
# 57395              Power Hitters              0.0  Selective / Moderate
# 57396              Power Hitters              0.0  Selective / Moderate
# 57397           Balanced Hitters              0.0  Selective / Moderate
# 57398  Hitters With Good Contact              2.0   Aggressive Fastball
#
#        Cluster_Group.2 Swinging Tendencies  player_id_y  \
# 0                  1.0            Balanced       596133
# 1                  0.0          Aggressive       596133
# 2                  2.0           Selective       596133
# 3                  1.0            Balanced       596133
# 4                  2.0           Selective       592454
# ...                ...                 ...          ...
# 57394              2.0           Selective       677960
# 57395              1.0            Balanced       677960
# 57396              0.0          Aggressive       571927
# 57397              0.0          Aggressive       571927
# 57398              2.0           Selective       571927
#
#       last_name, first_name_y  kmeans_quality_cluster  \
# 0                Weaver, Luke                       1
# 1                Weaver, Luke                       1
# 2                Weaver, Luke                       1
# 3                Weaver, Luke                       1
# 4               Kahnle, Tommy                       8
# ...                       ...                     ...
# 57394          Weathers, Ryan                       3
# 57395          Weathers, Ryan                       3
# 57396            Matz, Steven                       0
# 57397            Matz, Steven                       0
# 57398            Matz, Steven                       0
#
#                               quality_archetype  impact_cluster  \
# 0                  League-Average Pitch Quality               2
# 1                  League-Average Pitch Quality               2
# 2                  League-Average Pitch Quality               2
# 3                  League-Average Pitch Quality               2
# 4               Changeup Specialists (Elite CH)               2
# ...                                         ...             ...
# 57394              Weak Fastball Group (Bad FF)               0
# 57395              Weak Fastball Group (Bad FF)               0
# 57396  Fastball Generalists (Good FF + Good SI)               3
# 57397  Fastball Generalists (Good FF + Good SI)               3
# 57398  Fastball Generalists (Good FF + Good SI)               3
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3      Balanced Positive Arsenal (Mild Impact Gains)
# 4      Balanced Positive Arsenal (Mild Impact Gains)
# ...                                              ...
# 57394    FF Liability Pitchers (Bad Fastball Impact)
# 57395    FF Liability Pitchers (Bad Fastball Impact)
# 57396              Sinker Aces (Elite Sinker Impact)
# 57397              Sinker Aces (Elite Sinker Impact)
# 57398              Sinker Aces (Elite Sinker Impact)
#
# [57399 rows x 20 columns]

# %%
#Finding the Rules
#Outcomes 2022
transactions22 = complete[['events','Swinging Tendencies','quality_archetype']].copy()

# %%
for col in transactions22.columns:
    transactions22[col] = transactions22[col].astype(str)
    transactions22[col] = col + "_" + transactions22[col]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
transactionLists = transactions22.values.tolist()

# %%
#One Hot Encoding 
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)

# %%
#Apirori ItemSet
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)

# %%
#Rules (Swinging Techinque and quality_archetype)	
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.3)

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
firstCleaned.sort_values(by='confidence', ascending=False, inplace=True)
display(firstCleaned)
# Out:
#                                           antecedents         consequents  \
# 52  (quality_archetype_League-Average Pitch Qualit...  (events_field_out)
# 20                    (Swinging Tendencies_Selective)  (events_field_out)
# 55  (quality_archetype_Weak Fastball Group (Bad FF...  (events_field_out)
# 37  (quality_archetype_Weak Breaking Ball Group (B...  (events_field_out)
# 32  (quality_archetype_Four-Seam Aces (Elite FF Qu...  (events_field_out)
# 38   (quality_archetype_Weak Fastball Group (Bad FF))  (events_field_out)
# 31  (quality_archetype_Fastball Generalists (Good ...  (events_field_out)
# 33   (quality_archetype_League-Average Pitch Quality)  (events_field_out)
# 35       (quality_archetype_Sinkers Get Hit (Bad SI))  (events_field_out)
# 0                    (Swinging Tendencies_Aggressive)  (events_field_out)
# 42  (Swinging Tendencies_Aggressive, quality_arche...  (events_field_out)
# 36         (quality_archetype_Slider Aces (Elite SL))  (events_field_out)
# 10                     (Swinging Tendencies_Balanced)  (events_field_out)
# 47  (Swinging Tendencies_Balanced, quality_archety...  (events_field_out)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 52            0.146791            0.403044  0.065363    0.445282  1.104796
# 20            0.366854            0.403044  0.160478    0.437444  1.085349
# 55            0.054038            0.403044  0.023510    0.435075  1.079471
# 37            0.059172            0.403044  0.024039    0.406250  1.007953
# 32            0.119665            0.403044  0.048490    0.405215  1.005386
# 38            0.149631            0.403044  0.060592    0.404943  1.004711
# 31            0.079315            0.403044  0.032079    0.404455  1.003499
# 33            0.397976            0.403044  0.160924    0.404356  1.003254
# 35            0.063993            0.403044  0.025723    0.401961  0.997311
# 0             0.325464            0.403044  0.130496    0.400954  0.994813
# 42            0.129340            0.403044  0.051181    0.395711  0.981805
# 36            0.066750            0.403044  0.025673    0.384615  0.954275
# 10            0.307682            0.403044  0.112071    0.364241  0.903725
# 47            0.121845            0.403044  0.044379    0.364228  0.903691
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 52               1.0  0.006200    1.076142       0.111175  0.134917
# 20               1.0  0.012620    1.061148       0.124201  0.263329
# 55               1.0  0.001731    1.056698       0.077826  0.054225
# 37               1.0  0.000190    1.005399       0.008387  0.054861
# 32               1.0  0.000260    1.003650       0.006085  0.102253
# 38               1.0  0.000284    1.003191       0.005514  0.123134
# 31               1.0  0.000112    1.002368       0.003787  0.071243
# 33               1.0  0.000522    1.002202       0.005387  0.251406
# 35               1.0 -0.000069    0.998188      -0.002872  0.058287
# 0                1.0 -0.000680    0.996510      -0.007671  0.218216
# 42               1.0 -0.000949    0.987864      -0.020842  0.106361
# 36               1.0 -0.001230    0.970053      -0.048835  0.057807
# 10               1.0 -0.011939    0.938966      -0.133356  0.187204
# 47               1.0 -0.004730    0.938945      -0.108226  0.092358
#
#     certainty  kulczynski
# 52   0.070754    0.303728
# 20   0.057625    0.417804
# 55   0.053656    0.246703
# 37   0.005370    0.232946
# 32   0.003636    0.262762
# 38   0.003181    0.277640
# 31   0.002362    0.242023
# 33   0.002197    0.401813
# 35  -0.001815    0.232891
# 0   -0.003502    0.362364
# 42  -0.012285    0.261349
# 36  -0.030872    0.224157
# 10  -0.065002    0.321151
# 47  -0.065025    0.237169

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions22Part2 = complete[['events','Hitter_Types','impact_archetype']].copy()
display(transactions22Part2)
for col in transactions22Part2.columns:
    transactions22Part2[col] = transactions22Part2[col].astype(str)
    transactions22Part2[col] = col + "_" + transactions22Part2[col]
transactionListsPart2 = transactions22Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.5)
# Out:
#           events               Hitter_Types  \
# 0      field_out           Balanced Hitters
# 1         single           Balanced Hitters
# 2      strikeout              Power Hitters
# 3      strikeout              Power Hitters
# 4      strikeout           Balanced Hitters
# ...          ...                        ...
# 60054       walk           Balanced Hitters
# 60055     double  Hitters With Good Contact
# 60056  field_out           Balanced Hitters
# 60057  strikeout              Power Hitters
# 60058  field_out           Balanced Hitters
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3                  Slider Aces (Elite Slider Impact)
# 4      Balanced Positive Arsenal (Mild Impact Gains)
# ...                                              ...
# 60054  Balanced Positive Arsenal (Mild Impact Gains)
# 60055  Balanced Positive Arsenal (Mild Impact Gains)
# 60056               Four-Seam Aces (Elite FF Impact)
# 60057               Four-Seam Aces (Elite FF Impact)
# 60058               Four-Seam Aces (Elite FF Impact)
#
# [60059 rows x 3 columns]

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
display(clean)
# Out:
#                                           antecedents         consequents  \
# 52  (quality_archetype_League-Average Pitch Qualit...  (events_field_out)
# 20                    (Swinging Tendencies_Selective)  (events_field_out)
# 55  (quality_archetype_Weak Fastball Group (Bad FF...  (events_field_out)
# 37  (quality_archetype_Weak Breaking Ball Group (B...  (events_field_out)
# 32  (quality_archetype_Four-Seam Aces (Elite FF Qu...  (events_field_out)
# 38   (quality_archetype_Weak Fastball Group (Bad FF))  (events_field_out)
# 31  (quality_archetype_Fastball Generalists (Good ...  (events_field_out)
# 33   (quality_archetype_League-Average Pitch Quality)  (events_field_out)
# 35       (quality_archetype_Sinkers Get Hit (Bad SI))  (events_field_out)
# 0                    (Swinging Tendencies_Aggressive)  (events_field_out)
# 42  (Swinging Tendencies_Aggressive, quality_arche...  (events_field_out)
# 36         (quality_archetype_Slider Aces (Elite SL))  (events_field_out)
# 10                     (Swinging Tendencies_Balanced)  (events_field_out)
# 47  (Swinging Tendencies_Balanced, quality_archety...  (events_field_out)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 52            0.146791            0.403044  0.065363    0.445282  1.104796
# 20            0.366854            0.403044  0.160478    0.437444  1.085349
# 55            0.054038            0.403044  0.023510    0.435075  1.079471
# 37            0.059172            0.403044  0.024039    0.406250  1.007953
# 32            0.119665            0.403044  0.048490    0.405215  1.005386
# 38            0.149631            0.403044  0.060592    0.404943  1.004711
# 31            0.079315            0.403044  0.032079    0.404455  1.003499
# 33            0.397976            0.403044  0.160924    0.404356  1.003254
# 35            0.063993            0.403044  0.025723    0.401961  0.997311
# 0             0.325464            0.403044  0.130496    0.400954  0.994813
# 42            0.129340            0.403044  0.051181    0.395711  0.981805
# 36            0.066750            0.403044  0.025673    0.384615  0.954275
# 10            0.307682            0.403044  0.112071    0.364241  0.903725
# 47            0.121845            0.403044  0.044379    0.364228  0.903691
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 52               1.0  0.006200    1.076142       0.111175  0.134917
# 20               1.0  0.012620    1.061148       0.124201  0.263329
# 55               1.0  0.001731    1.056698       0.077826  0.054225
# 37               1.0  0.000190    1.005399       0.008387  0.054861
# 32               1.0  0.000260    1.003650       0.006085  0.102253
# 38               1.0  0.000284    1.003191       0.005514  0.123134
# 31               1.0  0.000112    1.002368       0.003787  0.071243
# 33               1.0  0.000522    1.002202       0.005387  0.251406
# 35               1.0 -0.000069    0.998188      -0.002872  0.058287
# 0                1.0 -0.000680    0.996510      -0.007671  0.218216
# 42               1.0 -0.000949    0.987864      -0.020842  0.106361
# 36               1.0 -0.001230    0.970053      -0.048835  0.057807
# 10               1.0 -0.011939    0.938966      -0.133356  0.187204
# 47               1.0 -0.004730    0.938945      -0.108226  0.092358
#
#     certainty  kulczynski
# 52   0.070754    0.303728
# 20   0.057625    0.417804
# 55   0.053656    0.246703
# 37   0.005370    0.232946
# 32   0.003636    0.262762
# 38   0.003181    0.277640
# 31   0.002362    0.242023
# 33   0.002197    0.401813
# 35  -0.001815    0.232891
# 0   -0.003502    0.362364
# 42  -0.012285    0.261349
# 36  -0.030872    0.224157
# 10  -0.065002    0.321151
# 47  -0.065025    0.237169

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions22Part3 = complete[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
display(transactions22Part3)
for col in transactions22Part3.columns:
    transactions22Part3[col] = transactions22Part3[col].astype(str)
    transactions22Part3[col] = col + "_" + transactions22Part3[col]
transactionListsPart3 = transactions22Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.03)
# Out:
#           events               Hitter_Types       Ball Preference  \
# 0      field_out           Balanced Hitters  Selective / Moderate
# 1         single           Balanced Hitters  Selective / Moderate
# 2      strikeout              Power Hitters  Selective / Moderate
# 3      strikeout              Power Hitters  Selective / Moderate
# 4      strikeout           Balanced Hitters  Selective / Moderate
# ...          ...                        ...                   ...
# 60054       walk           Balanced Hitters  Selective / Moderate
# 60055     double  Hitters With Good Contact   Aggressive Fastball
# 60056  field_out           Balanced Hitters   Aggressive Fastball
# 60057  strikeout              Power Hitters   Aggressive Fastball
# 60058  field_out           Balanced Hitters  Selective / Moderate
#
#                                     impact_archetype
# 0      Balanced Positive Arsenal (Mild Impact Gains)
# 1      Balanced Positive Arsenal (Mild Impact Gains)
# 2      Balanced Positive Arsenal (Mild Impact Gains)
# 3                  Slider Aces (Elite Slider Impact)
# 4      Balanced Positive Arsenal (Mild Impact Gains)
# ...                                              ...
# 60054  Balanced Positive Arsenal (Mild Impact Gains)
# 60055  Balanced Positive Arsenal (Mild Impact Gains)
# 60056               Four-Seam Aces (Elite FF Impact)
# 60057               Four-Seam Aces (Elite FF Impact)
# 60058               Four-Seam Aces (Elite FF Impact)
#
# [60059 rows x 4 columns]

# %%
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)
display(cleansedDF)
# Out:
#                                            antecedents         consequents  \
# 152  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 68            (Hitter_Types_Hitters With Good Contact)  (events_field_out)
# 489  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 429  (Hitter_Types_Hitters With Good Contact, impac...  (events_field_out)
# 303  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# ..                                                 ...                 ...
# 256  (Ball Preference_Aggressive Fastball, impact_a...       (events_walk)
# 33              (Ball Preference_Selective / Moderate)     (events_double)
# 49                     (Hitter_Types_Balanced Hitters)     (events_double)
# 95   (impact_archetype_Balanced Positive Arsenal (M...     (events_double)
# 6                (Ball Preference_Aggressive Fastball)     (events_double)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 152            0.142010            0.413627  0.066152    0.465822  1.126191
# 68             0.211908            0.413627  0.097954    0.462246  1.117543
# 489            0.075159            0.413627  0.034533    0.459459  1.110807
# 429            0.112173            0.413627  0.051350    0.457771  1.106724
# 303            0.069898            0.413627  0.031802    0.454979  1.099974
# ..                  ...                 ...       ...         ...       ...
# 256            0.281906            0.079638  0.021745    0.077137  0.968586
# 33             0.468223            0.047020  0.022511    0.048078  1.022491
# 49             0.542467            0.047020  0.025741    0.047452  1.009187
# 95             0.529546            0.047020  0.024992    0.047195  1.003719
# 6              0.531777            0.047020  0.024509    0.046089  0.980197
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 152               1.0  0.007412    1.097713       0.130597  0.135145
# 68                1.0  0.010303    1.090411       0.133462  0.185666
# 489               1.0  0.003445    1.084791       0.107861  0.076021
# 429               1.0  0.004952    1.081412       0.108616  0.108230
# 303               1.0  0.002890    1.075872       0.097718  0.070402
# ..                ...       ...         ...            ...       ...
# 256               1.0 -0.000705    0.997289      -0.043213  0.063995
# 33                1.0  0.000495    1.001111       0.041363  0.045686
# 49                1.0  0.000234    1.000454       0.019897  0.045661
# 95                1.0  0.000093    1.000184       0.007877  0.045310
# 6                 1.0 -0.000495    0.999024      -0.041363  0.044217
#
#      certainty  kulczynski
# 152   0.089015    0.312877
# 68    0.082915    0.349531
# 489   0.078163    0.271474
# 429   0.075283    0.290958
# 303   0.070522    0.265932
# ..         ...         ...
# 256  -0.002718    0.175094
# 33    0.001110    0.263416
# 49    0.000453    0.297451
# 95    0.000184    0.289355
# 6    -0.000977    0.283668
#
# [83 rows x 14 columns]

# %%
#2023 Data
transactions23 = complete2[['events','Swinging Tendencies','quality_archetype']].copy()
for col in transactions23.columns:
    transactions23[col] = transactions23[col].astype(str)
    transactions23[col] = col + "_" + transactions23[col]
transactionLists = transactions23.values.tolist()
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.3)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
firstCleaned.sort_values(by='confidence', ascending=False, inplace=True)
display(firstCleaned)
# Out:
#                                           antecedents         consequents  \
# 52  (quality_archetype_League-Average Pitch Qualit...  (events_field_out)
# 20                    (Swinging Tendencies_Selective)  (events_field_out)
# 55  (quality_archetype_Weak Fastball Group (Bad FF...  (events_field_out)
# 37  (quality_archetype_Weak Breaking Ball Group (B...  (events_field_out)
# 32  (quality_archetype_Four-Seam Aces (Elite FF Qu...  (events_field_out)
# 38   (quality_archetype_Weak Fastball Group (Bad FF))  (events_field_out)
# 31  (quality_archetype_Fastball Generalists (Good ...  (events_field_out)
# 33   (quality_archetype_League-Average Pitch Quality)  (events_field_out)
# 35       (quality_archetype_Sinkers Get Hit (Bad SI))  (events_field_out)
# 0                    (Swinging Tendencies_Aggressive)  (events_field_out)
# 42  (Swinging Tendencies_Aggressive, quality_arche...  (events_field_out)
# 36         (quality_archetype_Slider Aces (Elite SL))  (events_field_out)
# 10                     (Swinging Tendencies_Balanced)  (events_field_out)
# 47  (Swinging Tendencies_Balanced, quality_archety...  (events_field_out)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 52            0.146791            0.403044  0.065363    0.445282  1.104796
# 20            0.366854            0.403044  0.160478    0.437444  1.085349
# 55            0.054038            0.403044  0.023510    0.435075  1.079471
# 37            0.059172            0.403044  0.024039    0.406250  1.007953
# 32            0.119665            0.403044  0.048490    0.405215  1.005386
# 38            0.149631            0.403044  0.060592    0.404943  1.004711
# 31            0.079315            0.403044  0.032079    0.404455  1.003499
# 33            0.397976            0.403044  0.160924    0.404356  1.003254
# 35            0.063993            0.403044  0.025723    0.401961  0.997311
# 0             0.325464            0.403044  0.130496    0.400954  0.994813
# 42            0.129340            0.403044  0.051181    0.395711  0.981805
# 36            0.066750            0.403044  0.025673    0.384615  0.954275
# 10            0.307682            0.403044  0.112071    0.364241  0.903725
# 47            0.121845            0.403044  0.044379    0.364228  0.903691
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 52               1.0  0.006200    1.076142       0.111175  0.134917
# 20               1.0  0.012620    1.061148       0.124201  0.263329
# 55               1.0  0.001731    1.056698       0.077826  0.054225
# 37               1.0  0.000190    1.005399       0.008387  0.054861
# 32               1.0  0.000260    1.003650       0.006085  0.102253
# 38               1.0  0.000284    1.003191       0.005514  0.123134
# 31               1.0  0.000112    1.002368       0.003787  0.071243
# 33               1.0  0.000522    1.002202       0.005387  0.251406
# 35               1.0 -0.000069    0.998188      -0.002872  0.058287
# 0                1.0 -0.000680    0.996510      -0.007671  0.218216
# 42               1.0 -0.000949    0.987864      -0.020842  0.106361
# 36               1.0 -0.001230    0.970053      -0.048835  0.057807
# 10               1.0 -0.011939    0.938966      -0.133356  0.187204
# 47               1.0 -0.004730    0.938945      -0.108226  0.092358
#
#     certainty  kulczynski
# 52   0.070754    0.303728
# 20   0.057625    0.417804
# 55   0.053656    0.246703
# 37   0.005370    0.232946
# 32   0.003636    0.262762
# 38   0.003181    0.277640
# 31   0.002362    0.242023
# 33   0.002197    0.401813
# 35  -0.001815    0.232891
# 0   -0.003502    0.362364
# 42  -0.012285    0.261349
# 36  -0.030872    0.224157
# 10  -0.065002    0.321151
# 47  -0.065025    0.237169

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions23Part2 = complete2[['events','Hitter_Types','impact_archetype']].copy()
for col in transactions23Part2.columns:
    transactions23Part2[col] = transactions23Part2[col].astype(str)
    transactions23Part2[col] = col + "_" + transactions23Part2[col]
transactionListsPart2 = transactions23Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.003)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
display(clean)
# Out:
#                                            antecedents         consequents  \
# 111  (Hitter_Types_Hitters With Good Contact, impac...  (events_field_out)
# 20            (Hitter_Types_Hitters With Good Contact)  (events_field_out)
# 82   (Hitter_Types_Balanced Hitters, impact_archety...  (events_field_out)
# 76   (Hitter_Types_Balanced Hitters, impact_archety...  (events_field_out)
# 3                      (Hitter_Types_Balanced Hitters)  (events_field_out)
# 51   (impact_archetype_Balanced Positive Arsenal (M...  (events_field_out)
# 54   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_field_out)
# 53   (impact_archetype_FF Liability Pitchers (Bad F...  (events_field_out)
# 87   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_field_out)
# 56   (impact_archetype_Sinker Liability Pitchers (S...  (events_field_out)
# 58   (impact_archetype_Slider Aces (Elite Slider Im...  (events_field_out)
# 118  (Hitter_Types_Power Hitters, impact_archetype_...  (events_field_out)
# 33                        (Hitter_Types_Power Hitters)  (events_field_out)
# 70   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_strikeout)
# 37                        (Hitter_Types_Power Hitters)  (events_strikeout)
# 130  (Hitter_Types_Power Hitters, impact_archetype_...  (events_strikeout)
# 67   (impact_archetype_Balanced Positive Arsenal (M...  (events_strikeout)
# 7                      (Hitter_Types_Balanced Hitters)  (events_strikeout)
# 100  (Hitter_Types_Balanced Hitters, impact_archety...  (events_strikeout)
# 69   (impact_archetype_FF Liability Pitchers (Bad F...  (events_strikeout)
# 24            (Hitter_Types_Hitters With Good Contact)  (events_strikeout)
# 22            (Hitter_Types_Hitters With Good Contact)     (events_single)
# 65   (impact_archetype_FF Liability Pitchers (Bad F...     (events_single)
# 5                      (Hitter_Types_Balanced Hitters)     (events_single)
# 63   (impact_archetype_Balanced Positive Arsenal (M...     (events_single)
# 94   (Hitter_Types_Balanced Hitters, impact_archety...     (events_single)
# 34                        (Hitter_Types_Power Hitters)     (events_single)
# 123  (Hitter_Types_Power Hitters, impact_archetype_...     (events_single)
# 39                        (Hitter_Types_Power Hitters)       (events_walk)
# 73   (impact_archetype_Balanced Positive Arsenal (M...       (events_walk)
# 106  (Hitter_Types_Balanced Hitters, impact_archety...       (events_walk)
# 9                      (Hitter_Types_Balanced Hitters)       (events_walk)
# 1                      (Hitter_Types_Balanced Hitters)     (events_double)
# 49   (impact_archetype_Balanced Positive Arsenal (M...     (events_double)
# 61   (impact_archetype_Balanced Positive Arsenal (M...   (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 111            0.101834            0.403044  0.047219    0.463684  1.150453
# 20             0.177219            0.403044  0.080437    0.453885  1.126141
# 82             0.071918            0.403044  0.030048    0.417815  1.036646
# 76             0.290561            0.403044  0.120210    0.413717  1.026479
# 3              0.501313            0.403044  0.205353    0.409630  1.016339
# 51             0.577342            0.403044  0.234939    0.406932  1.009645
# 54             0.120689            0.403044  0.048919    0.405335  1.005683
# 53             0.144628            0.403044  0.058528    0.404680  1.004059
# 87             0.060080            0.403044  0.024270    0.403957  1.002264
# 56             0.063036            0.403044  0.025079    0.397852  0.987118
# 58             0.058000            0.403044  0.021876    0.377171  0.935804
# 118            0.184946            0.403044  0.067510    0.365024  0.905667
# 33             0.321468            0.403044  0.117255    0.364748  0.904981
# 70             0.120689            0.212419  0.029636    0.245554  1.155990
# 37             0.321468            0.212419  0.078093    0.242925  1.143615
# 130            0.184946            0.212419  0.044627    0.241296  1.135945
# 67             0.577342            0.212419  0.121217    0.209957  0.988412
# 7              0.501313            0.212419  0.104839    0.209129  0.984513
# 100            0.290561            0.212419  0.060047    0.206659  0.972886
# 69             0.144628            0.212419  0.027027    0.186872  0.879734
# 24             0.177219            0.212419  0.029487    0.166387  0.783297
# 22             0.177219            0.144051  0.029091    0.164151  1.139539
# 65             0.144628            0.144051  0.021859    0.151142  1.049226
# 5              0.501313            0.144051  0.072364    0.144349  1.002069
# 63             0.577342            0.144051  0.082385    0.142698  0.990609
# 94             0.290561            0.144051  0.041176    0.141713  0.983770
# 34             0.321468            0.144051  0.042596    0.132505  0.919849
# 123            0.184946            0.144051  0.024253    0.131137  0.910356
# 39             0.321468            0.083640  0.030626    0.095270  1.139045
# 73             0.577342            0.083640  0.048474    0.083960  1.003825
# 106            0.290561            0.083640  0.023626    0.081311  0.972158
# 9              0.501313            0.083640  0.040351    0.080490  0.962338
# 1              0.501313            0.047318  0.024517    0.048907  1.033574
# 49             0.577342            0.047318  0.026862    0.046527  0.983283
# 61             0.577342            0.036471  0.021414    0.037090  1.016978
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 111               1.0  0.006175    1.113066       0.145604  0.103175
# 20                1.0  0.009010    1.093095       0.136138  0.160930
# 82                1.0  0.001062    1.025370       0.038090  0.067537
# 76                1.0  0.003101    1.018203       0.036361  0.209646
# 3                 1.0  0.003301    1.011155       0.032237  0.293779
# 51                1.0  0.002244    1.006555       0.022602  0.315165
# 54                1.0  0.000276    1.003852       0.006427  0.103029
# 53                1.0  0.000237    1.002748       0.004726  0.119654
# 87                1.0  0.000055    1.001531       0.002404  0.055303
# 56                1.0 -0.000327    0.991377      -0.013737  0.056868
# 58                1.0 -0.001501    0.958457      -0.067881  0.049812
# 118               1.0 -0.007032    0.940123      -0.113313  0.129707
# 33                1.0 -0.012311    0.939714      -0.134004  0.193089
# 70                1.0  0.003999    1.043920       0.153461  0.097655
# 37                1.0  0.009807    1.040295       0.185076  0.171333
# 130               1.0  0.005341    1.038061       0.146832  0.126515
# 67                1.0 -0.001421    0.996884      -0.026990  0.181315
# 7                 1.0 -0.001649    0.995840      -0.030579  0.172180
# 100               1.0 -0.001673    0.992740      -0.037799  0.135567
# 69                1.0 -0.003695    0.968582      -0.137799  0.081895
# 24                1.0 -0.008158    0.944780      -0.251633  0.081874
# 22                1.0  0.003562    1.024048       0.148827  0.099565
# 65                1.0  0.001026    1.008354       0.054849  0.081926
# 5                 1.0  0.000149    1.000348       0.004140  0.126289
# 63                1.0 -0.000781    0.998422      -0.021937  0.128927
# 94                1.0 -0.000679    0.997276      -0.022727  0.104658
# 34                1.0 -0.003712    0.986691      -0.113803  0.100718
# 123               1.0 -0.002388    0.985138      -0.107793  0.079586
# 39                1.0  0.003739    1.012854       0.179905  0.081783
# 73                1.0  0.000185    1.000349       0.009016  0.079140
# 106               1.0 -0.000677    0.997465      -0.038803  0.067392
# 9                 1.0 -0.001579    0.996574      -0.072768  0.074092
# 1                 1.0  0.000796    1.001670       0.065138  0.046779
# 49                1.0 -0.000457    0.999170      -0.038669  0.044935
# 61                1.0  0.000357    1.000643       0.039498  0.036147
#
#      certainty  kulczynski
# 111   0.101581    0.290420
# 20    0.085166    0.326729
# 82    0.024742    0.246184
# 76    0.017878    0.355986
# 3     0.011032    0.459567
# 51    0.006512    0.494921
# 54    0.003837    0.263355
# 53    0.002740    0.274948
# 87    0.001529    0.232087
# 56   -0.008698    0.230038
# 58   -0.043343    0.215724
# 118  -0.063690    0.266262
# 33   -0.064154    0.327835
# 70    0.042072    0.192535
# 37    0.038734    0.305281
# 130   0.036666    0.225692
# 67   -0.003125    0.390304
# 7    -0.004177    0.351339
# 100  -0.007313    0.244671
# 69   -0.032437    0.157053
# 24   -0.058447    0.152601
# 22    0.023484    0.183050
# 65    0.008284    0.151445
# 5     0.000348    0.323349
# 63   -0.001580    0.357309
# 94   -0.002731    0.213779
# 34   -0.013489    0.214103
# 123  -0.015087    0.149752
# 39    0.012691    0.230718
# 73    0.000349    0.331755
# 106  -0.002541    0.181891
# 9    -0.003438    0.281461
# 1     0.001668    0.283525
# 49   -0.000830    0.307109
# 61    0.000643    0.312117

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions23Part3 = complete2[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
for col in transactions23Part3.columns:
    transactions23Part3[col] = transactions23Part3[col].astype(str)
    transactions23Part3[col] = col + "_" + transactions23Part3[col]
transactionListsPart3 = transactions23Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.003)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)

display(cleansedDF)
# Out:
#                                            antecedents         consequents  \
# 140  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 381  (Hitter_Types_Hitters With Good Contact, impac...  (events_field_out)
# 68            (Hitter_Types_Hitters With Good Contact)  (events_field_out)
# 476  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 237  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# ..                                                 ...                 ...
# 25              (Ball Preference_Selective / Moderate)     (events_double)
# 292  (Ball Preference_Selective / Moderate, impact_...     (events_double)
# 97   (impact_archetype_Balanced Positive Arsenal (M...     (events_double)
# 29              (Ball Preference_Selective / Moderate)   (events_home_run)
# 109  (impact_archetype_Balanced Positive Arsenal (M...   (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 140            0.066470            0.403044  0.031155    0.468703  1.162908
# 381            0.101834            0.403044  0.047219    0.463684  1.150453
# 68             0.177219            0.403044  0.080437    0.453885  1.126141
# 476            0.064637            0.403044  0.029239    0.452363  1.122364
# 237            0.110750            0.403044  0.049283    0.444991  1.104074
# ..                  ...                 ...       ...         ...       ...
# 25             0.761181            0.047318  0.036322    0.047718  1.008459
# 292            0.440291            0.047318  0.020572    0.046723  0.987420
# 97             0.577342            0.047318  0.026862    0.046527  0.983283
# 29             0.761181            0.036471  0.029025    0.038131  1.045526
# 109            0.577342            0.036471  0.021414    0.037090  1.016978
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 140               1.0  0.004364    1.123583       0.150061  0.071071
# 381               1.0  0.006175    1.113066       0.145604  0.103175
# 68                1.0  0.009010    1.093095       0.136138  0.160930
# 476               1.0  0.003188    1.090056       0.116558  0.066689
# 237               1.0  0.004646    1.075578       0.106004  0.106096
# ..                ...       ...         ...            ...       ...
# 25                1.0  0.000305    1.000420       0.035124  0.047039
# 292               1.0 -0.000262    0.999376      -0.022256  0.044047
# 97                1.0 -0.000457    0.999170      -0.038669  0.044935
# 29                1.0  0.001264    1.001726       0.182330  0.037762
# 109               1.0  0.000357    1.000643       0.039498  0.036147
#
#      certainty  kulczynski
# 140   0.109990    0.273001
# 381   0.101581    0.290420
# 68    0.085166    0.326729
# 476   0.082616    0.262454
# 237   0.070268    0.283633
# ..         ...         ...
# 25    0.000420    0.407669
# 292  -0.000625    0.240737
# 97   -0.000830    0.307109
# 29    0.001723    0.416983
# 109   0.000643    0.312117
#
# [77 rows x 14 columns]

# %%
#2024 Data
transactions24 = complete3[['events','Swinging Tendencies','quality_archetype']].copy()
for col in transactions24.columns:
    transactions24[col] = transactions24[col].astype(str)
    transactions24[col] = col + "_" + transactions24[col]
transactionLists = transactions24.values.tolist()
EncodeData= TransactionEncoder()
listofItems = EncodeData.fit(transactionLists).transform(transactionLists)
EncodedInformation = pd.DataFrame(listofItems, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.3)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
firstCleaned = associationRules.loc[eventsFilter]
firstCleaned.sort_values(by='lift', ascending=False, inplace=True)
display(firstCleaned)
# Out:
#                                           antecedents         consequents  \
# 53  (quality_archetype_League-Average Pitch Qualit...  (events_field_out)
# 23                    (Swinging Tendencies_Selective)  (events_field_out)
# 31  (quality_archetype_Weak Breaking Ball Group (B...  (events_field_out)
# 30       (quality_archetype_Sinkers Get Hit (Bad SI))  (events_field_out)
# 39  (Swinging Tendencies_Aggressive, quality_arche...  (events_field_out)
# 32   (quality_archetype_Weak Fastball Group (Bad FF))  (events_field_out)
# 0                    (Swinging Tendencies_Aggressive)  (events_field_out)
# 28   (quality_archetype_League-Average Pitch Quality)  (events_field_out)
# 36  (Swinging Tendencies_Aggressive, quality_arche...  (events_field_out)
# 26  (quality_archetype_Fastball Generalists (Good ...  (events_field_out)
# 27  (quality_archetype_Four-Seam Aces (Elite FF Qu...  (events_field_out)
# 45  (Swinging Tendencies_Balanced, quality_archety...  (events_field_out)
# 48  (Swinging Tendencies_Balanced, quality_archety...  (events_field_out)
# 10                     (Swinging Tendencies_Balanced)  (events_field_out)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 53            0.120141            0.408091  0.054304    0.452001  1.107600
# 23            0.286224            0.408091  0.128940    0.450484  1.103882
# 31            0.053625            0.408091  0.023223    0.433073  1.061218
# 30            0.061935            0.408091  0.026237    0.423629  1.038075
# 39            0.050071            0.408091  0.021168    0.422756  1.035936
# 32            0.145055            0.408091  0.060297    0.415686  1.018611
# 0             0.343403            0.408091  0.140891    0.410279  1.005361
# 28            0.417377            0.408091  0.170055    0.407438  0.998401
# 36            0.143016            0.408091  0.057771    0.403947  0.989846
# 26            0.079148            0.408091  0.031882    0.402818  0.987078
# 27            0.109235            0.408091  0.043189    0.395375  0.968840
# 45            0.154219            0.408091  0.057980    0.375960  0.921266
# 48            0.053241            0.408091  0.020000    0.375654  0.920517
# 10            0.370372            0.408091  0.138260    0.373301  0.914749
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 53               1.0  0.005275    1.080129       0.110412  0.114583
# 23               1.0  0.012134    1.077146       0.131842  0.228060
# 31               1.0  0.001340    1.044067       0.060956  0.052962
# 30               1.0  0.000962    1.026958       0.039100  0.059121
# 39               1.0  0.000734    1.025405       0.036518  0.048439
# 32               1.0  0.001102    1.012998       0.021371  0.122344
# 0                1.0  0.000751    1.003710       0.008121  0.230741
# 28               1.0 -0.000272    0.998899      -0.002741  0.259463
# 36               1.0 -0.000593    0.993048      -0.011829  0.117103
# 26               1.0 -0.000417    0.991170      -0.014017  0.070016
# 27               1.0 -0.001389    0.978969      -0.034848  0.091089
# 45               1.0 -0.004955    0.948512      -0.091772  0.114965
# 48               1.0 -0.001727    0.948048      -0.083579  0.045318
# 10               1.0 -0.012885    0.944487      -0.128933  0.215963
#
#     certainty  kulczynski
# 53   0.074184    0.292535
# 23   0.071621    0.383221
# 31   0.042207    0.244990
# 30   0.026251    0.243961
# 39   0.024776    0.237313
# 32   0.012831    0.281720
# 0    0.003696    0.377761
# 28  -0.001102    0.412074
# 36  -0.007001    0.272756
# 26  -0.008909    0.240471
# 27  -0.021483    0.250603
# 45  -0.054283    0.259018
# 48  -0.054799    0.212332
# 10  -0.058776    0.356049

# %%
#Second One (Hitter_Types + Impact Archetype)
transactions24Part2 = complete3[['events','Hitter_Types','impact_archetype']].copy()
for col in transactions24Part2.columns:
    transactions24Part2[col] = transactions24Part2[col].astype(str)
    transactions24Part2[col] = col + "_" + transactions24Part2[col]
transactionListsPart2 = transactions24Part2.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart2 = EncodeData.fit(transactionListsPart2).transform(transactionListsPart2)
EncodedInformation = pd.DataFrame(listofItemsPart2, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.003)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)
clean = associationRules.loc[eventsFilter]
clean.sort_values(by='lift', ascending=False, inplace=True)
clean.sort_values(by='confidence', ascending=False, inplace=True)
display(clean)
# Out:
#                                            antecedents         consequents  \
# 99   (Hitter_Types_Hitters With Good Contact, impac...  (events_field_out)
# 18            (Hitter_Types_Hitters With Good Contact)  (events_field_out)
# 76   (Hitter_Types_Balanced Hitters, impact_archety...  (events_field_out)
# 70   (Hitter_Types_Balanced Hitters, impact_archety...  (events_field_out)
# 52   (impact_archetype_Sinker Liability Pitchers (S...  (events_field_out)
# 3                      (Hitter_Types_Balanced Hitters)  (events_field_out)
# 49   (impact_archetype_FF Liability Pitchers (Bad F...  (events_field_out)
# 47   (impact_archetype_Balanced Positive Arsenal (M...  (events_field_out)
# 50   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_field_out)
# 106  (Hitter_Types_Power Hitters, impact_archetype_...  (events_field_out)
# 112  (Hitter_Types_Power Hitters, impact_archetype_...  (events_field_out)
# 29                        (Hitter_Types_Power Hitters)  (events_field_out)
# 64   (impact_archetype_Four-Seam Aces (Elite FF Imp...  (events_strikeout)
# 33                        (Hitter_Types_Power Hitters)  (events_strikeout)
# 124  (Hitter_Types_Power Hitters, impact_archetype_...  (events_strikeout)
# 7                      (Hitter_Types_Balanced Hitters)  (events_strikeout)
# 61   (impact_archetype_Balanced Positive Arsenal (M...  (events_strikeout)
# 88   (Hitter_Types_Balanced Hitters, impact_archety...  (events_strikeout)
# 63   (impact_archetype_FF Liability Pitchers (Bad F...  (events_strikeout)
# 22            (Hitter_Types_Hitters With Good Contact)  (events_strikeout)
# 20            (Hitter_Types_Hitters With Good Contact)     (events_single)
# 57   (impact_archetype_Balanced Positive Arsenal (M...     (events_single)
# 59   (impact_archetype_FF Liability Pitchers (Bad F...     (events_single)
# 5                      (Hitter_Types_Balanced Hitters)     (events_single)
# 117  (Hitter_Types_Power Hitters, impact_archetype_...     (events_single)
# 30                        (Hitter_Types_Power Hitters)     (events_single)
# 82   (Hitter_Types_Balanced Hitters, impact_archety...     (events_single)
# 35                        (Hitter_Types_Power Hitters)       (events_walk)
# 67   (impact_archetype_Balanced Positive Arsenal (M...       (events_walk)
# 9                      (Hitter_Types_Balanced Hitters)       (events_walk)
# 94   (Hitter_Types_Balanced Hitters, impact_archety...       (events_walk)
# 45   (impact_archetype_Balanced Positive Arsenal (M...     (events_double)
# 1                      (Hitter_Types_Balanced Hitters)     (events_double)
# 55   (impact_archetype_Balanced Positive Arsenal (M...   (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 99             0.114601            0.408091  0.053154    0.463819  1.136558
# 18             0.188732            0.408091  0.087005    0.460999  1.129648
# 76             0.082127            0.408091  0.034739    0.422995  1.036523
# 70             0.290946            0.408091  0.122842    0.422216  1.034612
# 52             0.059879            0.408091  0.024983    0.417224  1.022381
# 3              0.484172            0.408091  0.201850    0.416898  1.021581
# 49             0.169794            0.408091  0.070297    0.414016  1.014519
# 47             0.602084            0.408091  0.248506    0.412743  1.011401
# 50             0.101134            0.408091  0.038903    0.384668  0.942605
# 106            0.196537            0.408091  0.072510    0.368939  0.904061
# 112            0.055297            0.408091  0.020262    0.366415  0.897875
# 29             0.327096            0.408091  0.119236    0.364527  0.893251
# 64             0.101134            0.215979  0.027736    0.274246  1.269780
# 33             0.327096            0.215979  0.080350    0.245646  1.137358
# 124            0.196537            0.215979  0.047109    0.239695  1.109805
# 7              0.484172            0.215979  0.103608    0.213990  0.990790
# 61             0.602084            0.215979  0.127807    0.212275  0.982847
# 88             0.290946            0.215979  0.061569    0.211617  0.979801
# 63             0.169794            0.215979  0.033659    0.198235  0.917843
# 22             0.188732            0.215979  0.032021    0.169667  0.785569
# 20             0.188732            0.144950  0.030541    0.161820  1.116385
# 57             0.602084            0.144950  0.087231    0.144883  0.999534
# 59             0.169794            0.144950  0.024373    0.143546  0.990313
# 5              0.484172            0.144950  0.068625    0.141737  0.977829
# 117            0.196537            0.144950  0.027596    0.140413  0.968698
# 30             0.327096            0.144950  0.045785    0.139973  0.965665
# 82             0.290946            0.144950  0.040610    0.139581  0.962957
# 35             0.327096            0.079967  0.029600    0.090493  1.131632
# 67             0.602084            0.079967  0.047039    0.078127  0.976999
# 9              0.484172            0.079967  0.036464    0.075312  0.941796
# 94             0.290946            0.079967  0.021272    0.073114  0.914304
# 45             0.602084            0.044757  0.027492    0.045661  1.020202
# 1              0.484172            0.044757  0.021917    0.045266  1.011385
# 55             0.602084            0.034774  0.021133    0.035099  1.009354
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 99                1.0  0.006387    1.103935       0.135702  0.113205
# 18                1.0  0.009985    1.098159       0.141468  0.170659
# 76                1.0  0.001224    1.025831       0.038389  0.076270
# 70                1.0  0.004110    1.024447       0.047181  0.213195
# 52                1.0  0.000547    1.015673       0.023286  0.056397
# 3                 1.0  0.004264    1.015103       0.040953  0.292362
# 49                1.0  0.001006    1.010112       0.017239  0.138493
# 47                1.0  0.002801    1.007923       0.028329  0.326265
# 50                1.0 -0.002369    0.961935      -0.063443  0.082716
# 106               1.0 -0.007695    0.937959      -0.116669  0.136267
# 112               1.0 -0.002305    0.934222      -0.107460  0.045724
# 29                1.0 -0.014249    0.931447      -0.150814  0.193579
# 64                1.0  0.005893    1.080285       0.236367  0.095846
# 33                1.0  0.009704    1.039327       0.179475  0.173645
# 124               1.0  0.004661    1.031192       0.123143  0.128922
# 7                 1.0 -0.000963    0.997469      -0.017702  0.173681
# 61                1.0 -0.002231    0.995297      -0.042017  0.185159
# 88                1.0 -0.001269    0.994466      -0.028253  0.138247
# 63                1.0 -0.003013    0.977869      -0.097324  0.095592
# 22                1.0 -0.008741    0.944224      -0.251757  0.085920
# 20                1.0  0.003184    1.020127       0.128505  0.100747
# 57                1.0 -0.000041    0.999921      -0.001171  0.132208
# 59                1.0 -0.000238    0.998360      -0.011646  0.083938
# 5                 1.0 -0.001556    0.996256      -0.042106  0.122436
# 117               1.0 -0.000892    0.994722      -0.038662  0.087917
# 30                1.0 -0.001628    0.994213      -0.050188  0.107410
# 82                1.0 -0.001562    0.993760      -0.051461  0.102737
# 35                1.0  0.003443    1.011573       0.172863  0.078418
# 67                1.0 -0.001107    0.998005      -0.055859  0.074076
# 9                 1.0 -0.002254    0.994967      -0.106992  0.069103
# 94                1.0 -0.001994    0.992607      -0.116754  0.060840
# 45                1.0  0.000544    1.000947       0.049763  0.044388
# 1                 1.0  0.000247    1.000534       0.021824  0.043227
# 55                1.0  0.000196    1.000337       0.023289  0.034322
#
#      certainty  kulczynski
# 99    0.094150    0.297035
# 18    0.089385    0.337099
# 76    0.025181    0.254061
# 70    0.023863    0.361616
# 52    0.015431    0.239222
# 3     0.014879    0.455759
# 49    0.010010    0.293138
# 47    0.007860    0.510846
# 50   -0.039571    0.239999
# 106  -0.066145    0.273310
# 112  -0.070410    0.208032
# 29   -0.073598    0.328353
# 64    0.074318    0.201332
# 33    0.037839    0.308836
# 124   0.030249    0.228906
# 7    -0.002537    0.346851
# 61   -0.004725    0.402015
# 88   -0.005564    0.248343
# 63   -0.022632    0.177040
# 22   -0.059071    0.158964
# 20    0.019730    0.186259
# 57   -0.000079    0.373343
# 59   -0.001642    0.155848
# 5    -0.003759    0.307587
# 117  -0.005306    0.165399
# 30   -0.005821    0.227919
# 82   -0.006280    0.209875
# 35    0.011441    0.230323
# 67   -0.001999    0.333181
# 9    -0.005059    0.265652
# 94   -0.007448    0.169563
# 45    0.000947    0.329954
# 1     0.000533    0.267476
# 55    0.000337    0.321407

# %%
#Third One 
#(Hitter_Types + Ball Preference + Impact Archetype)
transactions24Part3 = complete3[['events','Hitter_Types','Ball Preference','impact_archetype']].copy()
for col in transactions24Part3.columns:
    transactions24Part3[col] = transactions24Part3[col].astype(str)
    transactions24Part3[col] = col + "_" + transactions24Part3[col]
transactionListsPart3 = transactions24Part3.values.tolist()
EncodeData= TransactionEncoder()
listofItemsPart3 = EncodeData.fit(transactionListsPart3).transform(transactionListsPart3)
EncodedInformation = pd.DataFrame(listofItemsPart3, columns=EncodeData.columns_)
frequentItemSetUsed = apriori(EncodedInformation, min_support = 0.02, use_colnames = True)
associationRules = association_rules(frequentItemSetUsed,metric='confidence',min_threshold = 0.003)
eventsFilter = []
for i in range(len(associationRules)):
    antecedent_items = associationRules.loc[i, 'antecedents']
    consequent_items = associationRules.loc[i, 'consequents']
    if len(consequent_items) != 1:
        continue
    if any('events' in item for item in consequent_items):
        eventsFilter.append(i)

cleansedDF = associationRules.loc[eventsFilter]
cleansedDF.sort_values(by='lift', ascending=False, inplace=True)
cleansedDF.sort_values(by='confidence', ascending=False, inplace=True)
display(cleansedDF)
# Out:
#                                            antecedents         consequents  \
# 462  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 361  (Hitter_Types_Hitters With Good Contact, impac...  (events_field_out)
# 193  (Hitter_Types_Hitters With Good Contact, Ball ...  (events_field_out)
# 64            (Hitter_Types_Hitters With Good Contact)  (events_field_out)
# 421  (Hitter_Types_Balanced Hitters, Ball Preferenc...  (events_field_out)
# ..                                                 ...                 ...
# 266  (Ball Preference_Selective / Moderate, impact_...     (events_double)
# 47                     (Hitter_Types_Balanced Hitters)     (events_double)
# 23              (Ball Preference_Selective / Moderate)     (events_double)
# 27              (Ball Preference_Selective / Moderate)   (events_home_run)
# 101  (impact_archetype_Balanced Positive Arsenal (M...   (events_home_run)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 462            0.101326            0.408091  0.047126    0.465096  1.139688
# 361            0.114601            0.408091  0.053154    0.463819  1.136558
# 193            0.166762            0.408091  0.076900    0.461137  1.129986
# 64             0.188732            0.408091  0.087005    0.460999  1.129648
# 421            0.067510            0.408091  0.028764    0.426065  1.044044
# ..                  ...                 ...       ...         ...       ...
# 266            0.508005            0.044757  0.023171    0.045612  1.019106
# 47             0.484172            0.044757  0.021917    0.045266  1.011385
# 23             0.842018            0.044757  0.037806    0.044899  1.003169
# 27             0.842018            0.034774  0.029913    0.035526  1.021617
# 101            0.602084            0.034774  0.021133    0.035099  1.009354
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 462               1.0  0.005776    1.106572       0.136387  0.101941
# 361               1.0  0.006387    1.103935       0.135702  0.113205
# 193               1.0  0.008846    1.098440       0.138055  0.154433
# 64                1.0  0.009985    1.098159       0.141468  0.170659
# 421               1.0  0.001213    1.031317       0.045240  0.064371
# ..                ...       ...         ...            ...       ...
# 266               1.0  0.000434    1.000896       0.038105  0.043753
# 47                1.0  0.000247    1.000534       0.021824  0.043227
# 23                1.0  0.000119    1.000149       0.019997  0.044531
# 27                1.0  0.000633    1.000779       0.133940  0.035322
# 101               1.0  0.000196    1.000337       0.023289  0.034322
#
#      certainty  kulczynski
# 462   0.096308    0.290288
# 361   0.094150    0.297035
# 193   0.089618    0.324788
# 64    0.089385    0.337099
# 421   0.030366    0.248274
# ..         ...         ...
# 266   0.000895    0.281662
# 47    0.000533    0.267476
# 23    0.000148    0.444793
# 27    0.000779    0.447873
# 101   0.000337    0.321407
#
# [77 rows x 14 columns]
